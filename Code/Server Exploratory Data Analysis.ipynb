# %%
# Import the pandas library to help read the data

import pandas as pd
import os

# %%
# Explore the anonymized csv 

anonDf = pd.read_csv("data/anon.csv")

# %%
# Count the total number of messages sent by each person
display(anonDf['username'].value_counts())

# Also find the total number of messages sent overall
print("Total number of messages sent:", anonDf.shape[0])
# Out:
# username
# author4     1851
# author2     1340
# author6      698
# author5      492
# author7      457
# author13     328
# author14     321
# author16     270
# author10     262
# author1      123
# author11      73
# author15      49
# author12      27
# author25      19
# author8       17
# author17      16
# author27      13
# author18      12
# author29      11
# author28      11
# author21      11
# author9       10
# author23       9
# author3        6
# author30       6
# author20       3
# author24       2
# author22       1
# author26       1
# author19       1
# author31       1
# Name: count, dtype: int64
# Total number of messages sent: 6441

# %%
# Find the total number of words sent by each person
anonDf['wordCount'] = anonDf['content'].apply(lambda x: len(x.split()))
display(anonDf.groupby('username')['wordCount'].sum())

# Also find the total overall word count
print("Total word count: ", anonDf['wordCount'].sum())
# Out:
# username
# author1       941
# author10     1406
# author11      871
# author12      226
# author13     3586
# author14     2850
# author15      259
# author16     2605
# author17      189
# author18      151
# author19       10
# author2     12415
# author20       18
# author21      128
# author22       36
# author23       73
# author24        5
# author25      131
# author26        5
# author27       84
# author28       71
# author29       64
# author3        42
# author30       55
# author31        4
# author4     18080
# author5      5528
# author6      5418
# author7      3216
# author8       138
# author9        52
# Name: wordCount, dtype: int64
# Total word count:  58657

# %%
# Find the average number of words per message per person
anonDf['wordCountPerMessage'] = anonDf['wordCount']
display(anonDf.groupby('username')['wordCountPerMessage'].mean())

# Also find the average number of words per message overall
print("Average number of words per message: ", anonDf['wordCountPerMessage'].mean())
# Out:
# username
# author1      7.650407
# author10     5.366412
# author11    11.931507
# author12     8.370370
# author13    10.932927
# author14     8.878505
# author15     5.285714
# author16     9.648148
# author17    11.812500
# author18    12.583333
# author19    10.000000
# author2      9.264925
# author20     6.000000
# author21    11.636364
# author22    36.000000
# author23     8.111111
# author24     2.500000
# author25     6.894737
# author26     5.000000
# author27     6.461538
# author28     6.454545
# author29     5.818182
# author3      7.000000
# author30     9.166667
# author31     4.000000
# author4      9.767693
# author5     11.235772
# author6      7.762178
# author7      7.037199
# author8      8.117647
# author9      5.200000
# Name: wordCountPerMessage, dtype: float64
# Average number of words per message:  9.106815711845986

# %%
# Look at all messages, count unique words

wordFrequency = {}

for i in range(len(anonDf)):
    # Skip NaN values
    if pd.isnull(anonDf.iloc[i, 1]):
        continue
    for word in anonDf.iloc[i, 1].split():
        if word in wordFrequency:
            wordFrequency[word] += 1
        else:
            wordFrequency[word] = 1

print('Number of distinct words used:', len(wordFrequency))

# Add the words to a list, sorted in descending order of frequency
wordList = sorted(wordFrequency, key=wordFrequency.get, reverse=True)


# Print the most used words by each person, and the most used words by both
numWordsToPrint = 15

# Most used words by both
printstr = 'The most used ' + str(numWordsToPrint) + ' words are: '
for i in range(numWordsToPrint):
    printstr += wordList[i]
    printstr += '(' + str(wordFrequency[wordList[i]]) + ' uses)'
    printstr += ', '
printstr = printstr[:-2]
printstr += '.'
print(printstr)
# Out:
# Number of distinct words used: 9813
# The most used 15 words are: the(1609 uses), I(1544 uses), to(1348 uses), a(1323 uses), it(788 uses), is(771 uses), and(766 uses), you(761 uses), of(664 uses), that(594 uses), be(579 uses), in(576 uses), for(548 uses), have(507 uses), on(397 uses).

# %%
# Add each message to a corpus. Each message is separated by a comma.

corpus = []
originalMessageIndexMap = {}
for i in range(len(anonDf)):
    # Skip over NaN values
    if pd.isnull(anonDf.iloc[i, 1]):
        continue
    # Skip over messages with only one word
    if len(anonDf.iloc[i, 1].split()) == 1:
        continue
    corpus.append(anonDf.iloc[i, 1])
    originalMessageIndexMap[len(corpus) - 1] = i
    
display(corpus)
# Out:
# ["or did my acid patch thing kill him off my turn? I don't think it did",
#  'pretty sure it was will but double check',
#  'I think will',
#  'Whoever went before Oliver',
#  "I think it was either me or fable, can't really remember",
#  'Cause they attacked him after he already died',
#  'not Oliver',
#  '<@&981382306663120919> who landed the killing blow on Borgbreill?',
#  'I would like to point out that William has inadvertently created the church of Hanzo',
#  'Btw <@&981382306663120919> give me 1 emotion your character would be feeling',
#  '0 17 -15 0 -2 14 -8',
#  '14 17 0 -3',
#  '18 21 18 4 15 13',
#  'Write message in alphabetical code\r\nSubtract the values of a looping code word',
#  '4 5 1 20 8',
#  '20 18 21 5',
#  '6 18 5 5 4 15 13',
#  '<@&981382306663120919> 30 minutes',
#  'Reminder <@&981382306663120919> Sunday at 5',
#  'Aight then I can run it instead of Gnome on 4/16',
#  'I currently have no preference for weekend',
#  'Sunday usually preferable',
#  "Then let's just move it to a weekend Wed was gonna be a pain for me anyway",
#  'Wake up at 3am Thursday',
#  'The next is the problem',
#  'Are you working that day <@318536129727168512> ?',
#  'i can ask for that day off',
#  'Can move it either in place of Gnome or King that week if it makes life easier',
#  'But I’ll manage',
#  'It’ll be rough',
#  '<@589289513788899348> \r\n<@318536129727168512>',
#  'Sounds good',
#  '(Not tomorrow)',
#  'Political views on next Wednesday night',
#  'Okay so William say Wednesday, Sat, or Sun works for him on this',
#  'But tldr is just this unless you are a crafter or caster that needs expensive components (diamond dust, onyx, etc)',
#  'So may need to buy a higher lvl scroll',
#  'Yeah but the CL of the scroll does need to be 2x whatever the items CL is',
#  'Make whole scroll is 50gp x CL and dc 20 + CL UMD',
#  '*Costly Spell Components:* Anyone trained in Spellcraft can salvage costly material or focus spell components from magic items. Each attempt requires destroying the item and 8 hours of work. An item can be broken down into a powder that can be used in place of gemstone dust as a material component. Otherwise, the item must have a spell requiring the component in its construction requirements to salvage that component. A successful Spellcraft check with a DC equal to 10 + the item’s caster level yields materials usable in place of that spell component worth two-thirds the item’s creation cost (one-third its market price). If you fail the check by 4 or less, the item is destroyed without yielding spell components, but you can try to salvage them again. If you fail the check by 5 or more, the item is destroyed and the spell components are ruined.',
#  '*Raw Magic Item Materials:* Anyone with an item creation feat can salvage the raw materials from magic items for the creation of new ones or repair of existing ones. You must have the item creation feat required for that item to salvage its raw materials. Each attempt requires destroying a magic item and 8 hours of work. If the item’s price is 500 gp or less, you can salvage its materials in only 2 hours. A successful Craft or Spellcraft check with a DC equal to 10 + the item’s caster level yields raw materials worth two-thirds the creation cost of the destroyed item (one-third the market price). If you fail the skill check by 4 or less, the item is destroyed but the materials can still be salvaged in a future attempt. If you fail the skill check by 5 or more, the item is destroyed and the materials are ruined. Salvaged raw materials can be used to create or repair any item made of similar materials or that shares any of the creation requirements as the original. Including the majority of the materials allows you to automatically meet any construction requirements of a new item that the salvaged item also required and reduces the construction or repair time by the proportion of the new item’s construction materials that are salvaged (with the usual minimum creation time). Spellbooks and formula books can be salvaged for magic inks and paper usable in formula books, scrolls, and spellbooks.\r\n.',
#  '*Raw Crafting Materials:* Anyone trained in the Craft skill can salvage raw materials from equipment for use in crafting or repair. You must carefully dismantle the item to be salvaged, resulting in the item’s destruction. If the item’s price is 1 gp or less, its materials can be salvaged with only 1 hour of work; otherwise it takes 8 hours to salvage crafting materials. A successful Craft check against the item’s creation DC + 5 yields raw materials worth one-quarter the item’s price. If you fail the Craft check by 4 or less, the item is destroyed but the materials can still be salvaged in a future attempt. If you fail the Craft check by 5 or more, the item is destroyed and the materials are ruined. Salvaged raw materials can be used to create or repair any item of the same materials and reduces the construction time by the proportion of the new item’s raw materials that are salvaged (minimum 8 hours).\r\n.',
#  '**Wrecked Magic Items Rules:**\r\nRepairing a magic item requires material components equal to half the cost to create the item, and requires half the time. The make whole spell can also repair a damaged (or even a destroyed) magic item—if the caster is high enough level.\r\n.',
#  'Works for me',
#  'Thinking night of 4/6 perhaps',
#  "That way I'm not split between it Gnome and Werewolves",
#  "This is finished btw I'm trying to run it soon",
#  '.\r\nCharacter level 10th | Mythic Tier 1st\r\n25 point-buy\r\n62,000 gp starting (+29,000gp for returning characters)\r\nPvp is allowed, Evil alignments are permitted (both must be disclosed to me and approved as nondisruptive)\r\nThe people of the Crown mainly speak Erutaki\r\n\r\nReturning Characters Note:\r\nThe 29,000gp is in addition to the gold retrieved from Borgbreill’s tomb\r\nTo restate the collected earnings from part 1:\r\nTristin: 50,000gp, 10,000gp in wrecked magic items\r\nEveryone else: 4,000gp, 1,000gp in wrecked magic items \r\n@everyone React with ❄️ if interested',
#  'Echos of the North (Part 2 of 2): The Fractured Spire\r\nThree years have passed since the inhabitants of the World’s Crown raced to find an ancient Sarkorian tomb. Now that the dust has settled, treasures have been pillaged, and travelers have returned home, silence has washed over the frigid tundra. After three years of peace, these chilling wastes have again proven to hold much more than initially appears.\r\n\r\nAfter months of unprecedented tremors shook the mountains of Golarion’s pole, the tallest tower of the Nameless Spires began to emit a strange field of magic. As quickly as the activity stirred the abominations that once called the Spires their home to flee, they shortly returned both greater in number and with strength unheard of for mortal creatures. The tower soon launched crackling energy into the clouds tearing the very sky asunder. As the cracks in the sky grew, it became evident that whoever armed the ancient tower plans to tear a rift into another plane. A catastrophe that could prove more lethal than the Worldwound. As the earth begins to tremble once again, it is clear that something must be done before Golarion itself is torn apart.\r\n\r\nThe Wandering Skum is again organizing parties, hoping the few remaining heroes are strong enough to save this land from the ancient powers that echo through the ice and snow. While locals fear the tower has been charging for millennia and that this was their true purpose, those who saw the mythical might of the warlord that lurked within that Sarkorian tomb can sense his power in the Spires.',
#  'Ima make tristin my favored enemy',
#  "Echos 2: It's Borgin' time",
#  '<@458413180893397022> dark 60ft',
#  'Replace head with snake or become human idk what to say',
#  'idk bro',
#  '<@151500793990742016> this +breastplate and axe seem good',
#  'we can pretend the snake holds on to the axe',
#  'He’s a nagaji',
#  'Here you go',
#  'Katar instead of sword',
#  'thats what my spirit looks like',
#  'Nothing like this and also no cape',
#  'you know something like this minus the guns lmao',
#  'bruh i forgot the snake existed',
#  'And a snake',
#  'sumn like this minus the cape',
#  'Got a preferance on token border?',
#  'close enough to my character',
#  '+Character images',
#  '120ft tremorsense',
#  '<@&981382306663120919> can I get everyones vision range?',
#  'Hey guys dont forget you +1 a stat every 4 lvls as normal',
#  'Copy of foundry link',
#  'Thought it was your address',
#  'Ah gotcha',
#  'i put that for the other peoples that will need to connect',
#  'Didnt need to copy but thanks',
#  'It is a checkbox for me',
#  'd3ecf5726d877f6b here is address so you can just copy/paste',
#  'Not I',
#  'Is anyone here opposed to starting at 1pm on Sunday',
#  "Also if you haven't played with me before you guys need to do some minor set up on your end",
#  "<@456034448194928641> <@151500793990742016> <@683040629391097921> What classes are ya'll planning on playing",
#  'I think most people can make it so Im gonna lock in on that day',
#  "Really don't think I can, not gonna have the time",
#  'uhhh sure',
#  '<@589289513788899348>  <@378709482953244672>',
#  'Should be good',
#  "I'm good",
#  'I’m good',
#  'So im chillin',
#  "I don't work",
#  'So <@&981382306663120919> July 10th',
#  'hehehey new mexico go brrr\r\n\r\nanyways i can do anything past maybe the 1st, 5th would be most convenient',
#  'What about the next week is everyone in town',
#  'Will be on plane',
#  'I cannot',
#  '<@589289513788899348> cannot',
#  'Should for me',
#  'Should for me',
#  'Hey <@&981382306663120919> does the 29th work for everyone',
#  "I'll ask off for the 25th",
#  'Good for the 29th',
#  'We’ll see',
#  'So how about the 25th or 29th?',
#  'Tristin couldnt',
#  'monday is a no but i currently see no problem with any other day. i assume you cant do sat?',
#  'Any other day is cool',
#  'I can’t do Monday or Tuesday of next week',
#  "I'm free Wednesday and Saturdays",
#  "What about ya'll?",
#  "I'm gonna have to push the date back <@&981382306663120919> mainly due to personal issues. What days are ya'll able to do next week?\r\nSunday night seems like it may be good",
#  'Just gotta make charkter',
#  "I'm still good",
#  'I’m good',
#  'im good i just need help with my character, either way is fine',
#  'All <@&981382306663120919> do I need to push back the date?\r\n1 person already cant make it what about you guys',
#  'In call if any one needs helpwith characters or jjst wants to chat',
#  "Remember <@&981382306663120919> We'll be playing on **Wednesday at 6:15**\r\n\r\nMake sure that your characters are ready. If you need help Ill be in call here from 6ish to 10ish for prep.",
#  'Epic style',
#  "Don't have work that day so I should be",
#  'can do! ill rush up and finish the character',
#  'Must be tired idk',
#  "I don't think you finished that first line",
#  'All good just dm what kinda build youre thinking (melee v ranged, martial v caster etc)',
#  'Honestly I don’t know and was hoping you or someone else could help me make one',
#  "Also Id like to know what the rest of ya'll are playing\r\n-Starr and Tristin I know what you guys are playing",
#  '<@&981382306663120919> you guys good for the 8th or?',
#  'I have the stuff ready ~~more or less~~',
#  'Should work then I think',
#  'Date on that?',
#  'Looks good for me, you, and Connor',
#  '<@458413180893397022> next wednesday.',
#  'Then it might be more like 7',
#  'I’m slow',
#  "Its only 5 if you aren't slow",
#  'Nice 6 hour walk there, just a casual stroll',
#  'Also it was just me who brought up wapmart 😔',
#  'but like anywhere in canton',
#  'I mean you can work at not walmart',
#  'It just pays alot',
#  "It's not",
#  'Why is walmart considered to be the only interesting place',
#  "Is there anywhere nearby he'd be interested in walking and/or biking to",
#  'no but',
#  "That's true",
#  "you don't have to work at walmart",
#  "But I'm ok",
#  'I dunno about tristin',
#  'I mean',
#  'but I could def go 5+',
#  '1.5 miles',
#  'How long was that bike ride',
#  'I biked for 6 months to my job',
#  "Also if there were days we didn't work together...",
#  'It will be a 3 hour walk one way at most',
#  'You walk',
#  'But how get job with no car',
#  'Ok hear me out, what if he got a job so he can buy a car? /s',
#  'I live in beaver dam, to say it’s out of his way is an understatement',
#  'give him a ride',
#  "You've told me that a billion times",
#  'I apologize',
#  'Don’t have car/ride',
#  'Come work at Walmart 😃',
#  'I’m prob not gonna have a job so basically any day',
#  'Needs to be before the 20th',
#  'Might be move idk',
#  'Theoretically that should work',
#  "I'm thinking a Monday but",
#  'Ik I have Sundays off',
#  'So does anyone have a favored day for this?',
#  'Just make sure to mention x skill cause y reason\r\nAs long as you can justify it Ill most likely approve it',
#  'I had that typed up but forgot to attach it the initial wrote up like a dumbass',
#  'I got that?',
#  'Btw anyone that submits a motive to me gains the following trait\r\n\r\nMotivated Adventurer:\r\nSelect a skill related to your background. That skill counts as a class skill for you. If the chosen skill is already a class skill then you gain a +2 trait bonus instead.',
#  'Added details about the local humanlanguage',
#  'Map of the Crown btw',
#  'Also pin that first message for me Tristin',
#  "Anyway can ya'll go react on the message so I don't have to scroll later",
#  'Hmm weird',
#  'and it is higher',
#  'No but finder of paths can',
#  'He has to roles that I don’t',
#  'Can Kingmaker 2 see it?',
#  'but you have the same roles as Connor so idk',
#  'I added you specifically to the channel',
#  'Yay I can see',
#  "He can't see it or divine pperogitive",
#  'Cause it has the same permissions as the other one shots',
#  "I honestly couldn't give you a reason he can't see it",
#  "Let's see <@280377735207976960> ?",
#  'What about now',
#  'and I can see them when looking here',
#  'From him',
#  'Connor can',
#  "I couldn't tell you why",
#  'Hey <@318536129727168512> apparently Jt and likely some others cant see this channel',
#  'Meant react lmao',
#  '@everyone who is interested please react here with a 🪙',
#  'Character level 8th\r\n25 point-buy\r\n33,000 gp starting\r\nPvp is allowed, Evil alignments are permitted (both must be disclosed to me and approved as nondisruptive)\r\nThe people of Nutaqq mainly speak Erutaki\r\n*Optional: Motive for finding the tomb\r\nAnyone that has a defined motive will gain the Motivated Adventurer Trait*',
#  "Echos of the North (Part 1 of 2):\r\nLegends and whispers among the travelers of Golarion's Crown speak of a lost tomb hidden in the deepest reaches of the frozen High Ice. The tomb, supposedly belonging to the ancient Sarkorian Warlord Borgbreill would likely contain riches and treasure worthy of the god-king's mythical status. In light of the recent closing of the Worldwound, travel in the region has seen a recent surge and the rumors of this frigid tomb have become increasingly popular throughout settlements near Sarkoris. It's only a matter of time before someone heads North and stumbles upon the tomb and the riches held within. \r\n\r\nLuckily for you, the Erutaki village of Nutaqq that borders the High Ice is rumored to be organizing parties for people hoping to find the tomb and strike it rich. Perhaps the echos of this lost tomb could contain your chance at glory.",
#  'I mean congrats I guess\r\nBut Arazni killong Urgotha was a pretty popular theory\r\nAnd Erastil dying would have been interesting',
#  'They were in my mind',
#  'I mean Erastil and Urgotha werent obviously safe',
#  "I think they'll do like 50-70% before war of immortals",
#  'They are getting all the obvious ones out of the way',
#  'My brain saw general and was like good enough',
#  'This is gnome general',
#  'Oh fuck',
#  '<@318536129727168512> good news',
#  'They took a minute today',
#  'Big W for big Magic',
#  'Oh shit\r\nAlso next god should be declared safe in like 2 min cause time change',
#  'Archive exists now',
#  'Does if it isn’t Mortimer',
#  "Cause aren't both immediates?",
#  "Doen't work with misfortune I think",
#  'Alcohol monk and alcohol barb combo',
#  'I thought you meant that feat',
#  'you are going to edge',
#  'on thursday',
#  '<@458413180893397022> are you excited to edge',
#  'I support it',
#  '<@458413180893397022> thoughts on everyone taking a level dip in dual cursed oracle',
#  'but already had it',
#  'was looking at buying it',
#  'Totally forgot I had the wayfinder of hidden strength',
#  'Did you find it or?',
#  '/grippli village',
#  'What was the buy price in blackwater',
#  "Misfortune (once per person) reroll a dice roll\r\nFortune (once per day) reroll my dice roll\r\nRewind Time (once per day) reroll my dice roll\r\nEternal Hope (once per day) reroll my nat 1\r\nFate's Shears (once per day) reroll a dice roll. Staggered next round.\r\nWayfinder of Hidden Strength (once per day) roll twice and take better\r\nFortunate Charm (once per day) reroll skill or concentration check\r\nSpellguard Bracers (three times per day) roll twice and take better on casting defensive",
#  'always act in surprise round gang',
#  'Rusty can be cool',
#  ':) wolves',
#  "You guys should level up by the end of this session then I'll shift to a few Wolves sessions",
#  '<@&927426307514581042> Sun?',
#  "Whatever lol isn't that big of a deal",
#  '*think I used for him',
#  'And I have the art I used for him',
#  "I feel like I'm going crazy I stg I remember you fighting the shade guy\r\nBut like Idk why I'd be missing his token",
#  'Oliver resisting the urge to among us',
#  'Wait its at 4:48 so it will be good',
#  "I have dr's appointment at 5 but it shouldn't last over",
#  '5:30 or 6 ish',
#  'cause it was planned like 3 weeks ago',
#  'determining if tomorrow is still happening',
#  'Monday night maybe?',
#  'But fair',
#  'I will be in another game',
#  'Tomorrow @6 <@&927426307514581042> ?',
#  'On phone with Mother',
#  'Was about to',
#  'I am in a word game with Law but will join when others do assuming we are still on',
#  'In theory you guys should be okay but the combats may be a little rough',
#  "I'm good either way",
#  'Fair\r\nShould we cancel then',
#  'Hey I jjust woke up and is in a lot  of pain. So I am probably not going to be able to do gnome today',
#  'This is a threat',
#  'That +1 carryin yall',
#  "Ya'll have the good ending",
#  'Foundry up one sec',
#  'unsure without looking at my character',
#  'I need it for political reasons',
#  '<@318536129727168512> Whats your curse DC',
#  'oh yes',
#  'Tomorrow per chance',
#  'shit fnome',
#  'Lets go wirh king then',
#  '<@589289513788899348> <@151489352164311040>',
#  'was planning on king but am good either way',
#  'We Kingin our makers or Mercin our Gnomes tomorrow',
#  "Hey <@&927426307514581042> <@&1064607664216231997> I'm gonna officially postpone Gnome/Wolves for a while until we get Kingmaker wrapped up\r\nShould only be a few weeks but it's mainly due to scheduling restrictions",
#  'Up for either, work till mon, I get off sometime between 6-9 if you want a late session',
#  'This was also an inquiry to which one had more interest',
#  'Fable working until Monday',
#  "I think I'm good",
#  'So were people feelin Gnomes, Werewolf, or busy',
#  'Gnome Setup',
#  'Curse BS',
#  'I heal it',
#  'Bulette has 3 Str dmg total btw',
#  'So Sunday at like 6:30?',
#  'I will be free this Sunday',
#  "Then I guess we aren't playing again this week\\",
#  'Fable usually works',
#  'So what is everyones status tomorrow <@&927426307514581042>',
#  'Ollie is going home to so scheduling is gonna suck',
#  'will be taken sunday@7',
#  'But I got stuff to do so im good',
#  'Yeah I said I thought fable was busy',
#  'Or my pet rock the dead child gave to me',
#  'Or rusty',
#  'Carson can play one of tristins characters',
#  'And havent finished preping',
#  'Well now there is actually no Gnome cause I have plans with Carson at 5',
#  'He thought there was no gnome because he thought I was busy when I was not busy',
#  'I already have made other plans cause based on that message I assumed you were busy',
#  'What time',
#  'Cause work wasn’t mentioned',
#  'I thought the yep was sarcasm',
#  'rip tris',
#  'That is when I am working',
#  'You wanna do a 10am session?',
#  '^ <@458413180893397022>',
#  'so no he||als||',
#  'Busy Sun too?',
#  'So no gnome',
#  'Yep\r\n10am-2pm sun',
#  'also sun is good',
#  'right now',
#  'Should be fine',
#  'What about sun?',
#  'going to Asheboro',
#  'K no King either I presume',
#  'prob cant tomorrow or saturday',
#  'So when gnomes <@&927426307514581042>',
#  'especially with us being up late vibing to coleman cawthorne',
#  'Im fine with earlier\r\nCounter is my skill issue in the sleep department on weekends',
#  'Work at 2 Sunday so it would have to be earlier than oli awake early',
#  'Mon good',
#  'Option of earlier session',
#  'Wb Mon Fable',
#  'Was planning Wolf Sun',
#  'I close this weekend',
#  'Any plans for any of the games?',
#  'yeah I was supposed to steal Noah but parents 😔',
#  'Fine by me',
#  'I can still do 6 potentially but',
#  'Is 7:30 to 9:30ish okay?',
#  'Attempting to',
#  '<@458413180893397022> are we gnoming tonight?',
#  'Knock yourself out lol',
#  'Yeah 6',
#  'Cuz I am finna take a nap till it starts <@458413180893397022>',
#  'Like at 6',
#  'When is this?',
#  'I am not sure how cognizant I will be because I am doing a close and then open, but I will try my best',
#  'Sunday is optimal',
#  '<@458413180893397022> looks like sunday will work',
#  'I am free tommorow and I open Sunday so I am free then',
#  "I'll have to wait and see past that cause I don't have a work schedule yet for next week",
#  "Up until today I would've said yes but I have to take a **Defensive Driving Class**",
#  'Monday night?',
#  'Wasteland game',
#  'Friday perhaps',
#  'I feel like they said they started working just weekends',
#  '<@151489352164311040> ?',
#  'I could do Sunday I think',
#  '<@&927426307514581042> this weekend?',
#  'Last time I did a version change 9 -> 10 it fucked stuff up so',
#  'I updated to v11',
#  'Hey <@&927426307514581042> can you check to make sure you foundry stuff was imported correctly',
#  "Yeah idk I'll just give them a rundown later and let them ask misc questions at placeholder social stuff",
#  'Yeah cause you level after hags',
#  'Cuz i remember iterative attacks',
#  'Or is it still 5',
#  "Ya'll are lvl 6 right",
#  "But yeah kinda how I'm leaning",
#  'give == write = true',
#  'one of us can give the run down post session',
#  "I'm good either way. Seems like for Fable sake it'd be simpler to do gnome.",
#  "The random encounters I have preped won't kill ya'll without Ollie (probably)",
#  'I will say that currently the cleric has not been reraced yet',
#  "So idk up to ya'll I guess, gnomes a player down or King I guess\r\n<@589289513788899348> this session was gonna be social -> travel -> maybe more social if you guys get there fast",
#  'factual information',
#  'same level I believe',
#  'Wait what level are we in King',
#  "Otherwise I'mj ust gonna go take a nap and be annoyed since this session was all exposition",
#  'I can',
#  'uh uh uh',
#  'Unless you think you can get back within a short time',
#  'King instead then?',
#  'i need to cart my dog to ephraims sorry i forgot to mention',
#  'oh wait i am not',
#  'At 6',
#  'We still good <@&927426307514581042>',
#  'might not be home in time 😔',
#  'Still gnoming tomorrow',
#  '11p my time 6p ur time <@151489352164311040>',
#  '<@318536129727168512> <@589289513788899348>',
#  'Okay, are you free on Thurs then?',
#  'Basically I am free after Thursday',
#  'I think we should also try to do king maker',
#  'Im free all week more or less (friday unknown)',
#  'Cause Ollie is going out of town',
#  'Here is my schedule for the next 2 weeks',
#  'When are you free',
#  'This Sunday not free',
#  'Next Sunday free',
#  'Am stupid',
#  'EST or GMT',
#  "yeah I think I'm free at 11",
#  'I think so',
#  'unsurprisingly maybe',
#  'Suprisingly yes',
#  'Sunday at 6 <@&927426307514581042> ?',
#  'Pov Gnome setting irl',
#  '<@151489352164311040> look in dms',
#  'Works for me',
#  'Melt his ass into a buckler or some shit',
#  'Cuz that seems cool',
#  'Also I can make sure I grab the piece of the graveknight I cut off',
#  'I don’t work Wednesday',
#  'What about Wednesday <@318536129727168512> ?',
#  'Probably yea',
#  'This means close Thutsday right <@151489352164311040> ?',
#  'Should be good',
#  '<@318536129727168512> usually works Wed if I remrmber correctly',
#  'Im gonna be out of town next week',
#  "Don't get schedule till tommorow, but I assume it will be the same as it has been the past 2 weeks, 2 - cl thurs - sun",
#  'Gnome this Thursday?',
#  '6:30 would be the start time',
#  'I do other kingmaker that day ||rarely|| so short session works',
#  'Long gnome session now',
#  'Short gnome session Tues then?',
#  'Off Mon -wed',
#  'King tomorrow (Mon) <@318536129727168512> ?',
#  'tell her i said happy birthday',
#  'mom birthday',
#  'btw prob cant wednesday',
#  'except monday',
#  "I think I'm good all those days",
#  'I am free from Mon to Thurs <@&927426307514581042> what are opinions',
#  'but ye that works :)',
#  "hey, it's only sometimes muted",
#  'Will be good then',
#  'Mainly <@589289513788899348> /Mr. Server mute',
#  'This works for me\r\n<@&927426307514581042> ?',
#  'I could do 5 on the morrow',
#  'Close rest of week',
#  'Oh yea off today, tommorow',
#  'Was working',
#  "Assuming I don't work then that sounds good",
#  'So King that morning possibly?',
#  "I'm busy Monday from 4 to whenever Greg is done with whatever he's wanting me to do (7:30 at the latest)",
#  'vice versa',
#  'so whichever we do gnome we could do kingmaker the other',
#  "I'm free monday and wednesday",
#  'Okay so I guess Ill start planing around when I get my schedule',
#  'i am good whenever',
#  'Work is starting to make me close somtimes, I find out my schedules for the next week every sunday\r\nAssuming I am not closing I should be good whenever',
#  '<@589289513788899348> <@151489352164311040>',
#  'Mon, wed, thur',
#  "So here's the conundrum I'm probably going to be closing most weekends this summer (including this weekend)",
#  '<@&927426307514581042> ➗',
#  'Everything else is small',
#  'So medium and Norgorber flavored',
#  'This gear is all abendego stuff btw',
#  'Sell chainshirts, shortswords, longswords, and maybe +1 hide armor',
#  'god i wish mercy was on my soul 😩',
#  'May god have mercy on your soul lawrence',
#  'gome <:wah:951310823366754334>',
#  'When gome?',
#  'Just a note Ollie has expressed they may not be able to make it depending on how their workload goes',
#  '<@&927426307514581042> yes 👁️🫦👁️',
#  'you are grandparents',
#  'No gnome this weekend going to grandparents',
#  'This dryer us giving me society moments',
#  "Foundry is up already if ya'll want/need to adjust items",
#  'Grabbing my laundry will be there like 1-2 min late',
#  'Works for me',
#  '4 work',
#  'I get off work at 3:30',
#  "<@&927426307514581042> ya'll intereded in starting earlier?",
#  'that looks sick',
#  'can grab a wayfinder to get +1 will',
#  'https://www.aonprd.com/MagicWondrousDisplay.aspx?FinalName=Ioun%20Stone%20Pink%20and%20Green%20Sphere <@151489352164311040> if you do not have a competence bonus to intimidate',
#  '+1 perception, sense motive, diplomacy, bluff, knowledge (religion), stealth',
#  'Dark Blue, Mulberry, Mossy, and Pale Ruby (Two flawed and Two cracked)',
#  'Yeah I dont see why not',
#  '<@458413180893397022> if I use mortician in place of heal would you allow competence bonus to heal to apply',
#  'Those are pretty nice for magus and cleric',
#  'https://www.aonprd.com/MagicWondrousDisplay.aspx?FinalName=Spellguard%20Bracers\r\nhttps://www.aonprd.com/AlchemicalReagents.aspx#:~:text=of%20the%20effect-,Void%20Shard,-Source%20Plane%2DHopper%27s\r\nhttps://www.aonprd.com/MagicWondrousDisplay.aspx?FinalName=Vest%20of%20Surgery\r\nhttps://www.aonprd.com/MagicWondrousDisplay.aspx?FinalName=Healer%27s%20Gloves\r\nhttps://www.aonprd.com/MagicWondrousDisplay.aspx?FinalName=Robe%20of%20Needles',
#  'Not the based Longtounge',
#  'like we were gonna do',
#  'Start there then go down',
#  'Ah the weird gripplis',
#  'My plan was to go west',
#  'I support tristins plan',
#  'Unless we have a good reason to go anywhere else east sound like the way to go',
#  'I think the plan was \r\nGo back to kobolds\r\nGo talk to gripplis\r\nGo south and get horse for paladin\r\nGo to other grippli place\r\nGo see if we can find Oliver mom',
#  "giant forest thing on the bottom left seems completely relevant to what's going on rn",
#  "Okay <@&927426307514581042> where tf ya'll going",
#  'nome mercy',
#  'No gnome this weekend btw',
#  'Dark-ness\r\nLocked away\r\nLirgen kings chose us to pay',
#  'Be there in a sec',
#  '<@151489352164311040> ?',
#  'oh yo sure!!',
#  "I'm down if others are",
#  'Starting at 5 otherwise',
#  "Ya'll want to start at 4?\r\nWas pretty helpful last night cause family",
#  "Gotcha\r\nGuess we'll just see how it goes",
#  'Like not the level of malicious where they just soley sundering my items to weaken me and not doing anything else',
#  '(Not counting curses cause perm)',
#  'I thought you were talking about bless lol',
#  'Shoutout to me having cast a spell that has lasted 5 sessions',
#  'As long as what they are doing actually helps them Idrc',
#  'Dont worry there are no grapplers...',
#  'As long as there is no grappling',
#  'Oh they wont be stupid\r\nJust a scale of how malicous',
#  'I am not opposed to them doing stupid shit',
#  'uh 7/10',
#  'This is a threat',
#  'Alright gamers how malicous do you want the enemy AI lol\r\nLooking over my tatics for that boss fight',
#  "what if I'm not doing either",
#  'is that a threat',
#  'Play gnome or go home',
#  'Sunday @5 <@&927426307514581042>',
#  'For a sec I thought that said "to host my insurance file"',
#  'So I can run Gnome\r\nBut, I may need to get <@318536129727168512> to host my instance file',
#  'K we can start in like 5-10 min',
#  'My b I did forget to announce this week',
#  'I should be good',
#  "I didn't even know we were starting",
#  "<@&927426307514581042> ya'll interested in starting a tad early?",
#  'Duality of man',
#  'my b',
#  'oh ok',
#  'I was just proving that dogs can climb',
#  'Not relevant to you',
#  'Its not even a joke\r\nIts a place',
#  '*insert some dick joke about ports*',
#  'I think you mean port',
#  "first airports, next you'll tell me waterports exist",
#  "I'll port your air",
#  "sorry I'm at the airport 🙂",
#  '<@151500793990742016> <@589289513788899348>  Gnoming time',
#  "Foundry is up if ya'll need to adjust anything",
#  'Assuming its at 5?',
#  'sunday still works',
#  'That was next weekend I was strupid',
#  'I was asking cause fable was questioning',
#  'Okay Sunday then',
#  'Wait <@&927426307514581042> Sat or Sun',
#  'Just checking in on stuff like normal',
#  'I know',
#  'I know',
#  'Im not on break like yall fyi',
#  'Oh fuck yea that would be next weekend',
#  'You gonna be in waynesville?',
#  'leaving waynesville?',
#  'If we do I would prefer Saturday cuz might be leaving Waynesville Sunday',
#  'We gnoming this weekend',
#  'on god',
#  'Not not not be like',
#  'Misclicked lol',
#  'I meant <@589289513788899348>',
#  '<@151489352164311040> ?',
#  '4 work?',
#  "<@&927426307514581042> Would ya'll be up to start slightly earlier?",
#  'Am good!',
#  'Sunday at 5 bte <@&927426307514581042>',
#  'Busy this weekend cause moving btw <@&927426307514581042>',
#  'That minimalist reticulated-triangle @ 5',
#  'tmr @ 5',
#  'Or Sunday',
#  '<@&927426307514581042> tomorrow 5?',
#  'Rest + in + piece',
#  'no 😔',
#  'Bro you gonna do what to their squirt gun',
#  '<@151500793990742016> do you understand',
#  'No gnome tonight',
#  'yeee :)',
#  'I think we started leanings towards getting eggs back after forge',
#  'Then if you have time visit the other Gripplies nearby',
#  'Just to make sure Ive preped correctly you guys are planning on finishing the forge this session?',
#  '2/5 said they couldnt come so if one more dips then we can do it',
#  'Probably not tonight unless UNCC cancels',
#  'Well\r\nWe trying to run it tonight or this weekend?',
#  '<@458413180893397022> what’s it lookin like',
#  'https://aonprd.com/MagicWondrousDisplay.aspx?FinalName=Ioun%20Stone%20Dusty%20Rose%20Prism\r\nhttps://aonprd.com/MagicWondrousDisplay.aspx?FinalName=Fate%27s%20Shears\r\nhttps://aonprd.com/MagicWondrousDisplay.aspx?FinalName=Wayfinder%20of%20Hidden%20Strength',
#  'Like 5ish minutes or is it gonna be like me calling my mom just now lmfao',
#  'Define a bit <@589289513788899348>',
#  'my dad called me, be there in a bit',
#  'Me with my stuffed animals on god <a:smh:823725775408201758>',
#  'Okay <@&927426307514581042> we are good',
#  "I swear my mother is obsessed with selling everything we own\r\nLike mf I've told you since I was 14 I'm keeping my lego collection",
#  'thats a terribly good idea',
#  'Good idea lmfao',
#  'start playing fire alarm sound on your computer',
#  'I have been in this call for an hour 💀',
#  "Mother won't stfu",
#  'I’m ready whenever btw',
#  'Uncle got here early let me fonish eating and we can start whenever people are ready',
#  'Ok 😔',
#  'Gonna stick with 7 need to meet up with my uncle',
#  'Probably good for 5',
#  'I also have plans with tristins parents after they are done with him so I might be late',
#  'Could be closer to 5',
#  'Just remembered my parents are visiting tomorrow. Probably only a day trip so should be gone by at most 7.',
#  '<@&927426307514581042> ?',
#  'Saturday at 5?',
#  '<@458413180893397022> our almighty savior please grace us with the time of our next session',
#  'Between two warm bowls I am created\r\nTo make the the fine maidens elated\r\nRound and shiny I gleam bright\r\nMuch like the fullest night\r\nSpeak my name',
#  'Am good 7',
#  'i EXIST',
#  'If <@151489352164311040> exists 7 otherwise 8:30 <@&927426307514581042>',
#  'i tihnk it got canceled',
#  'Fable what you end up doing with tgat lab',
#  'I might do it early and then just pop in for attendence',
#  'It is literally just writing and compiling something in C',
#  'no clases friday <:shrug:858187229779460116>',
#  'Will probably get out early though since its a lab',
#  'Have class from 5:30 to 8:15 friday',
#  'works for me',
#  'No <@&927426307514581042> today\r\nAiming for Friday night?',
#  'Shit sorry',
#  '<@458413180893397022> you alright?',
#  '<@&927426307514581042> reminder today at 7',
#  'also ill check sheet soon',
#  'no preference :)',
#  'Im good with Monday',
#  '<@589289513788899348> <@318536129727168512> ?',
#  'Personally prefer Mon as well but was unsure about yall',
#  "i get back Monday so I'm not to sure 😔",
#  'Am trying to visit waynessvile sat-sun so yea',
#  'Prefer monday',
#  'Also for our next session does anyone have a preference between Saturday, Sunday, or Monday from 7-10',
#  'Hey <@&927426307514581042>\r\nThe Foundry server has been migrated successfully\r\nI will be hosting the server for the bulk of they day please take the time today to join an look over your characters to ensure there has been no regression on your character sheets',
#  'Heads up <@&927426307514581042> \r\nI wont be running Gnome for a bit as I migrate my Foundry World between PCs. This should be resolved after next week',
#  'Mans gonna hit em with the Marth down tilt',
#  'Ok so large would mean natural reach of 10 ft\r\nSarissa does "A sarissa provides extended reach—tripling your reach rather than doubling it" So it would be 30ft and lunge would give me the extra 5ft meaning 35ft of reach',
#  'Lunge + big + sarissa = ranged attacks',
#  'Lunge + sarissa = fun',
#  '<@151489352164311040> Oliver has joined the party',
#  'you poverty',
#  'Ah i forgor, you decided to make you poverty a personality trait',
#  'What is that',
#  'The greatest anime duo',
#  'What you gonna do against the gloomblade^2',
#  'Lmao literal gloomblade',
#  'I need 8k to get an item that would complete my build',
#  'Hey guys could I borrow some money next time we are in town?',
#  'Yeah\r\nGonna roll initiative lmao',
#  'Higher for first? <@589289513788899348>',
#  'Roll off then mfs',
#  'I do not have any',
#  '<@589289513788899348> <@151489352164311040>',
#  'You guys got a preference who goes first there',
#  'Id like run at least one either Friday or Saturday',
#  'Im busy all day Mon and Thurs next week\r\nMon and Wed the week after',
#  'After 5:30pm mon - thurs and all day sat-sun',
#  'Hey <@&927426307514581042> Im looking to try and get all of the solo session done over the course of the next two weeks. Can I get some idea of when you guys are available?\r\nIf included images of my schedule below:',
#  "Brightblade's Bravo:\r\n3/day as an immediate action replace a save with Fort + demoralize enemies who witness\r\n\r\n<@151489352164311040> Was a sample I had for you",
#  'I will try to be silent when I go into his room them',
#  'DO NOT WAKE TRISTIN FROM HIS NAP I AM AWARE HE WILL BE LATE',
#  '- this message is from god',
#  "Oh fuck I didn't realize its at 6",
#  'it looks like mine is',
#  'Also updated and put foundry up please make sure your sheets are working <@&927426307514581042>',
#  'Pushing back to 6 so I have time to eat',
#  'I can',
#  '<@&927426307514581042> Saturday @5?',
#  'Also when are we doing gnome <@458413180893397022>',
#  '<@151500793990742016> you down or you got tennis',
#  'I am down',
#  "Ya'll still up for a (prob shorter) session?",
#  "Actually I think I can based on how much progress I've made this morning <@&927426307514581042>",
#  "that's ok!",
#  "nah you're chilliin",
#  'It is alright!',
#  'Hey <@&927426307514581042> I hate to do this but Im probably gonna need to cancel Gnome tomorrow\r\nIm sorry this keeps happening',
#  'yes :)',
#  'Might have tennis tho',
#  'Gnome @5 on Sunday work <@&927426307514581042>',
#  'No gnome cause wedding reception +family',
#  'so their roll was invalid',
#  'I disregarded fables roll cause we needed high or low before the roll',
#  'eight <:wah:951310823366754334>',
#  'You eight',
#  'xant speel',
#  'I see you edited smh',
#  '||Nunya|| forehead',
#  'it is in here',
#  'YOU WONT TELL ME WHY ITS DIFFEREN WTF',
#  'THATS NOT YOUR PFP',
#  "Oli doesn't know who I am",
#  'my head',
#  'tristin really just disregarded fables idea <:smh:744345376525516861>',
#  'High or low as good',
#  'Someone else should roll the other',
#  'I will roll one of them',
#  'Yo <@&927426307514581042> someone want to roll a 2d100 to see if the archon got sent to Brazil or not',
#  'good soup',
#  'Gnome @5 tomorrow <@&927426307514581042>',
#  'I got no shot of making it 💀',
#  "I'm going to tentatively say I may be able to run <@&927426307514581042> this Sunday\r\nThough I may have to cancel if I still haven't gotten all my work done",
#  'Hey no Gnome this weekend btw',
#  'No gnome tomorroe fyi',
#  'Btw note on that Kobold those guys had him like that for 2ish weeks',
#  '+3000gp  in potions',
#  '+1 Studded Leather',
#  'Hedge Cloak',
#  'It gnoming time?',
#  "Hey where are ya'll trying to go next session",
#  'will really try not to',
#  'Is <@589289513788899348>  going to be late again?',
#  '<@&927426307514581042> tomorrow at 4',
#  'Huh wands dont provoke',
#  'Im unsure on somatic',
#  'Also ~~currently~~ cannot use verbal component',
#  'may be a good trade',
#  'tbh doggie has good save',
#  'ahhh that',
#  'I was just saying no cloak or resistance + that',
#  'No he does',
#  ': (',
#  'rusty doesnt have that, does he :(',
#  'Reminder it is your shoulder slot',
#  ':) yes',
#  'Hedge cloak -> Rusty',
#  'Thatll prob end up being his armor and his hedge cloak',
#  'Ill just let yall distribute any notable items off him then give you potions with a gp value equal to 4th lvl character wealth - items you loot off him',
#  'Time to finish his transformation into a health potion',
#  'time to pat down his character',
#  'K so Ephraim is officially droping',
#  'Am I good to close foundry?',
#  'Dc is still 20 lol',
#  'If he puts a rank in umd',
#  'Can rusty use wands?',
#  '<@&927426307514581042> In Zeds 1st shipment of goods the most notable item is:\r\nWand of Magic Missile (1st) (23 of 50 charges) (345 gp)',
#  'I was entirely asleep until 1. Honestly Gnome times not really working out for me so I’m thinking I’ll need to drop out',
#  'Reminder <@&927426307514581042> \r\nUnless you guys prefer later',
#  'gimme 3-5 business days',
#  'ill come back to you',
#  'part 2',
#  'Bro I barely eat',
#  "I can't eat any if you're hoarding it all",
#  '*me thinking of somehting smart to say*',
#  'Come back when you stop eating garbage',
#  'hotdog is simply superior',
#  'my uncle loves sams club',
#  'of course i have',
#  'wdym i havent had',
#  'You haven’t had',
#  'Pizza better',
#  'bro i know them for they hotdogs\r\nima call em the hotdog people',
#  'but is it the hotdog people tho',
#  'the hotdog people?',
#  'Bro Sams club food on break',
#  'im ngl tho that 1 hour break was just nice',
#  'i see',
#  'Unsure on break',
#  '8.5 hours',
#  'Is it like 8 hours total with a 1 hour break?',
#  '<@318536129727168512> how long are your shifts?',
#  "Either would work this weekend but after that I'm gonna be working at Sams until 3:30",
#  'Nvm I could 1 to 4',
#  "Ideally that'd be even worse",
#  'Or was 3-6 better',
#  "But we'll see what happens",
#  'Ideally no',
#  'Sun 1-4 work again?',
#  'Current effect of the bear pelt',
#  'also ye',
#  'Am I good to close foundry',
#  "Aight its Gnomin' time\r\n~~Unless people want me to push it back some~~",
#  'Fair enough',
#  'Probably not I have to get homework and other stuff done today',
#  '1-4 Sunday',
#  'Well tonight was kingmaker/wotw not gnome',
#  'I will let you guys know whenever I am sure',
#  "There might be a chance I can't show up tonight",
#  'But yeah same time as the usual attempt unless someone is opposed',
#  'i work',
#  'would saturday work?',
#  'i am with parents then',
#  'I am good',
#  '<@&927426307514581042> sunday?',
#  'gnomeless behavior',
#  "Well since he didn't respond I'm gonna just say gnomeless behavior",
#  "<@492768651389435909> What's your existance like",
#  'Pretty much',
#  'Give me 6 hours and I will make him be able',
#  '<@318536129727168512>  so youre unable?',
#  'Fair enough',
#  'And with my family',
#  'Can’t access anything but phone',
#  'Uhh we’ll see',
#  'Good for me!',
#  'Sun at 5 work for you guys?',
#  'Thining about this more both days are equally good for me so idrc',
#  'Right now I prefer Sunday, but I may be getting a Sunday job soon so idk',
#  'anyways either works for me',
#  'depends on when my car is fixed',
#  'i just lose on this one ig',
#  'Gnome Sat or Sun?\r\nWhich works better <@&927426307514581042>',
#  'Not glock, gock',
#  'Shaking my glock',
#  'Even if I wasnt my desktop went to sleep somehow so no foundry',
#  'No gnome btw driving with law',
#  "I can do pf while I'm driving 🚗",
#  'Works for me',
#  'Move gnome to sunday then and kingmaker/wotw on saturday',
#  'If = not Saturday, friday',
#  'I forgor which',
#  'Also I have just realized I will be busy at Carowinds either this Saturday or next Saturday',
#  'Okay when do you not',
#  'I work',
#  'Sat 5-8 yay or nay',
#  'I might get a job sunday though',
#  'I just remembered the club I was planning on attending meets friday after 5',
#  'I should be free weekend',
#  'Could we do gnome on a weekend',
#  'We can do kingmaker or wotw saturday and sunday as well until further notice',
#  "I mean for now I'm good with friday that just might change soon",
#  "+ I have a roommate who'd prob want me off by 10ish but I'd have to ask",
#  "Yeah but I'm trying to sleep before 12 so I'd want off by 11",
#  'fyi kingmaker 2 is wednesday at 8',
#  'Unless we do it at like 8',
#  'I really think Friday nights is the inly time that jives with Fables schedule',
#  'Fridays at 5?',
#  'I school until 700 mon-thurs\r\nAnd have a meeting at 700 on Thurs\r\nBesides that I am free',
#  'Prefer not fri-sun cause wanna fill that with a jobe',
#  'Alright <@&927426307514581042> what days are good for gnome now',
#  'Though gnome should be fine depending on what you guys do',
#  'I have several statblocks I need to finish in various oneshots',
#  'I close and likely was gonna take off this week anyway',
#  'Hey gonna be a little late something came up, give me 15ish minutes',
#  'Sorry but I don’t think I’m gonna make it to the session, headache started so I’m soaking in the tub rn 😭',
#  'surprise doctors visit might make me a bit late',
#  "Can't 😔",
#  'Tomorrow at 6 <@&927426307514581042>',
#  'Sure if everyone else is cool eith it <@&927426307514581042>',
#  'Can we do this thursday',
#  'Good, if I had to suffer then so does everyone else',
#  "I won't have to imagine here soon",
#  'Imagine dying at orientation',
#  'Imagine not being in Raleigh',
#  'Computer being stupid, I’m trying to get it working so I’ll join once it is. You can go ahead and start if you want',
#  '6 should be good',
#  '<@492768651389435909> wby?',
#  'thank you',
#  "I'll roll back to 6 then to give you a chance then <@146626274066956288>",
#  'Bit I dont think swash gets much at level 4',
#  'You do in fact need to do thay',
#  'I need to level up rat tmk',
#  'I have no idea',
#  'I am good for 5',
#  "Okay but that doesn't answer my question",
#  "I'm at dentist",
#  'Is everyone still good for 5? <@&927426307514581042> Or does it need to be pushed to 6',
#  'What level are we now',
#  'my b',
#  'but still nc',
#  'i thought you said like the border of tennessee and nc',
#  'where the fuck were you going when you called me then',
#  'but might wanna put the foundry up so we can level our characters',
#  "Yeah I was just about to say I can't do today cause sister's birthday",
#  'K we can do tomorrow then',
#  'im good for today but would prefer tomorrow',
#  'Likely can tomorrow',
#  "But yah can't",
#  "And law says randy is in tennesee so he prob couldn't do today either",
#  'Ik randy cant do tommorow, no idea about today though',
#  '<@589289513788899348>  <@492768651389435909><@146626274066956288>?',
#  'Should be good for both',
#  'cant do tommorow tho, gotta go to raleigh',
#  '<@&927426307514581042> Today at 6 or tomorrow at 5?',
#  "If you guys test the bow and armor out for a bit you'll realize its +1",
#  'Ided by Ollie',
#  'When you get a strike',
#  ': )',
#  'close enough',
#  'mouse on mouse <:wah:951310823366754334>',
#  'stop 😭',
#  'Bruh at this point I think law just needs a character',
#  'Im thibking 6 if that works for everyone',
#  'yes! can do!',
#  'Am good',
#  "Because if I confirm I won't be able to",
#  'I can neither confirm or deny',
#  'works for me',
#  'Gnome tomorrow maybe?',
#  'Since I forgot to message yall about it earlier',
#  'I was thinking Id push back to 6 to give people time to get shit together',
#  'Also when, is it 5?',
#  'what level are we again',
#  'Uhh I might not be but you can go ahead without me if I can’t',
#  'uHhh sure',
#  'woah today',
#  'I CAN GNOME TODAY',
#  'I am good',
#  '<@&927426307514581042> I forgot to message yesterday',
#  'Are people available for Gnome today or should I just open Echoes in foundry',
#  'I was gonna put echos foundry on later but I guess not',
#  'My gpu is having a stroke',
#  'Well its a good thing I cancelled since Id have to anyway',
#  'We at watami',
#  'Idk but service has gotten shitty there',
#  'You in Waynesville rn?',
#  "My messages are sending slow but they'll get there",
#  'He said Wednesday he is typically off',
#  'Ah he has 2',
#  'Watami and walmart',
#  'Where is he working again?',
#  "Randall looked at me confused and said \r\nI don't have a day that I'm typically off",
#  'Good to know',
#  'I will say that I am employed by Starbucks, but that should only be mornings so I will be fine',
#  'But here is a question <@146626274066956288> when are you typically off?',
#  'No gnome today btw Ive been busy nonstop for about a week and need a day to chill',
#  'Can help build and know how to play casters lets go',
#  'Echo prep shuffle',
#  'K so',
#  'i work',
#  'Moms birthday Tuesday so…',
#  'On the condition Randall cant make it again Im considering cancelling to help people prep for Echos',
#  'Anyway <@&927426307514581042> Tuesday',
#  'Im a Meadowpunk Enthusiest myself',
#  '<@589289513788899348> crawling out of the hole',
#  'The kobold when crit rock',
#  'I am in fact home!',
#  '<@&927426307514581042> @6 btw\r\nUnless <@151489352164311040> also cant make it',
#  '||also not permament, just what im working with this week||',
#  'I was thinking the same thing',
#  'truly unfortunate',
#  "Law won't be able to show up to the ap he isn't in",
#  'So sad',
#  '|| I work 2-11 on tues - sat 😔 (except wednesday im 4-11)||',
#  'dealing with family',
#  'More of a just what my week looks like than a regular thing',
#  'Fri and Sat Im dealing with family',
#  'Tues, Wed, Thurs I work till 5:30',
#  'So Tuesday we were gonna have to start at 6 anyway',
#  'on that working man grind',
#  'Or fridat',
#  'Okay next week I have like Monday Thurs off',
#  'Would be helpful',
#  "I'll try and get them set",
#  'I have one or two a week',
#  'I rarely have a off',
#  "I don't have a usually",
#  'I can but others may be busy',
#  'Maybe 11 but idk about that',
#  'When you usually have off?',
#  'If we still wanna do it then, gotta be earlier',
#  'I go in at 4',
#  'I work Tuesday so',
#  'Then you go to work i assume',
#  "And we'd need to do it at like 1",
#  'gulpiegator is back on the grind',
#  'Well <@531348109347782656> was gonna run WotW tomorrow I think',
#  '<@458413180893397022> what do I have to bribe you to get you to do this tomorrow or something',
#  '25 damage on golem',
#  'Light has been rrstored to my lair',
#  'If so then yeah das fine',
#  'Wednesday as in tomorrow',
#  'Very rough encounter got even worse after Fable fell off a cliff',
#  'swashbuckler rat would save the day',
#  "~~I mean ya'll are getting ass blasted so~~",
#  "~~That's probably a good thing~~",
#  '~~Well his character isnt here anyway rn~~',
#  'Rand has work though',
#  'yes for me',
#  'Works for me',
#  '<@&927426307514581042> does Wednesday work for all you guys on the reschedule?',
#  'ephraim turn',
#  'Tetanus whooo',
#  'Hey starting at 6 because I needed to update my laptop and the walls on this map are a little unwieldy',
#  'Same thing though',
#  'Well I mean we might be moving Gnome to Mondays so',
#  'Tell them and if they still put you on for that day that’s their bad. They either get it or you go work at Watami',
#  'that wouldnt work',
#  'Not us',
#  'I meant to Walmart',
#  'it just now came to mind',
#  'Mfw you could say “hey can’t do Tuesdays”',
#  'Randall pulling a me',
#  'i have work tomorrow',
#  'oh yeah',
#  'That’s a really good point',
#  'we only murdered some of them',
#  'The entire party trying to be good people than shoving captives in a closet and subsequently murdering them',
#  'bit late bc i found it first but thank you',
#  'I vote <@492768651389435909>  out',
#  "*How adept of you, you'll know or not know later*",
#  'I think Ephraim is the impostor',
#  'You are the sus',
#  'smh, what a traitor',
#  'Gonna be late <@&927426307514581042> start at 6',
#  'If you’re a blind enthusiast it wouldn’t be clear would it',
#  "Clearly I'm a Blind Enthusiast",
#  'Even smaller enthusiast',
#  '<@492768651389435909> ?',
#  'I should be good',
#  'It would be super bad if your car just exploded tommorow',
#  'assuming your battery doesnt die again',
#  'I should be getting home between 6 and 8',
#  'no clue',
#  'Should be fine',
#  'tmr good',
#  '<@&927426307514581042>  what about the rest of you',
#  'I dont think randall would be able to tomorrow, unless he shows up super late',
#  'Its nothing dangerous',
#  'Or maybe thats anesthetics',
#  'I thought people who were diabetic had to be careful with meds though',
#  'At least theres that',
#  "I am medicated as hell though so I don't feel anything",
#  'That makes my tooth hurt thinking about it',
#  ...]

# %%
# Use TF-IDF to find the most important words in the corpus

from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(corpus)
tfidf_matrix
# Out:
# <6441x6576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 51229 stored elements in Compressed Sparse Row format>
