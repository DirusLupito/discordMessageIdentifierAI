# %%
# Import the pandas library to help read the data

import pandas as pd

# Read in the anonymized data from data/anon.csv
# This data can be assumed to already be cleaned

df = pd.read_csv("data/anon.csv")

# %%
# Split up the data into training and testing sets

X = df['content']
display(X)
Y = df['username']
display(Y)

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# Out:
# 0       or did my acid patch thing kill him off my tur...
# 1                pretty sure it was will but double check
# 2                                            I think will
# 3                              Whoever went before Oliver
# 4       I think it was either me or fable, can't reall...
#                               ...
# 6436    Okay so basically I just found out that this A...
# 6437                                              i think
# 6438                         Is the 16 before racial mods
# 6439                                    Aight sounds good
# 6440          20 point buy can't put a base stat above 16
# Name: content, Length: 6441, dtype: object
# 0       author1
# 1       author1
# 2       author2
# 3       author2
# 4       author3
#          ...
# 6436    author5
# 6437    author6
# 6438    author4
# 6439    author4
# 6440    author5
# Name: username, Length: 6441, dtype: object

# %%
#Extract alternative features from the data

#Vector of num words
numWordsTrain = []
numWordsTest = []
#Vector of num chars
numCharTrain = []
numCharTest = []
#Vector of avg char/word
avgCharTrain = []
avgCharTest = []

for msg in X_train:
    print(msg)
    #NumWords
    words = msg.count(" ") + 1
    numWordsTrain.append(words)
    #NumChars
    char = len(msg)
    numCharTrain.append(char)
    #AvgChar
    avgCharTrain.append(char / words)
# Display the length of the vectors
print(len(numWordsTrain))
print(len(numCharTrain))
print(len(avgCharTrain))

for msg in X_test:
    #NumWords
    words = msg.count(" ") + 1
    numWordsTest.append(words)
    #NumChars
    char = len(msg)
    numCharTest.append(char)
    #AvgChar
    avgCharTest.append(char / words)
# Out:
# shops will be included
# I'll make one tonight. I have yet to sit down and make my anathema and such yet, so it'll all work out and be done tonight. I'll dm a link to ya
# You could just walk into room and they have to make perception to know it is you
# How long was that bike ride
# Goblin campaign, enough said
# We should go through places on the way
# I was thinking the same thing
# It wasnt that he was actually living but that he was treated as being a living creature or something
# Who’s ready for tornado bat
# Yeah but idk if asmodeus was in on that bit
# For a sec I thought that said "to host my insurance file"
# lol lol
# My longest has been a slayer in the aformention 1e campaign (Kingmaker)
# Level 3 presumably
# Yea but it's a steam key
# Nvm I could 1 to 4
# I'm guessing yes
# noah when someone mispells his last name
# maybe chance
# Kobolds are like hamsters
# New map? What?
# I think he was referring to the orb having a %
# Ah kobold bards must throw down then
# I posted a summary of the overall story up to this point
# tj tried
# Those are pretty nice for magus and cleric
# anyone missing a story mission? If you are level 3 and I have your backstory you should have one.
# allows me to vet people outside of nepotism
# Basically the weirdness is because Undead's bleed immunity is listed in the definition of bleed dmg
# I always restart
# ill put that in my notes
# because that is the route that leads to sans being a boss battle
# Where is he working again?
# I’m gonna make him a fighter
# Was about to
# Gnome tomorrow
# Be there or be square
# Also <@378709482953244672> this  you
# Yeh it was a joke. Legiana is dead
# and the other feats
# Safi is great
# Works for me
# Seems I misremembered just checked
# i feel like being a living creature and having the undead trait are mutually exclusive
# Especially if you bust through the wall screaming
# I played starfinder 1e twice, and I just went for the biggest gun I could both times
# Here you go
# I love when maybe 100%
# Is the strix race allowed?
# Currently was plan
# They hate my beats cause of racism
# Carson can play one of tristins characters
# tiny rather
# <@&828644080443326494> tomorrow at 1 probably
# During the reveal stream, one of the devs was very stressed about a mention of an ability involving rainbows
# Tjs fat +8
# also wasn't planning on it cause of this
# Yeah but it got cured
# we got back at like 6:30 lol
# I think we can rule out Druid
# I think this is funnier
# Also tristin rn
# <@151489352164311040> the mission name is killing me
# Especially if it's limited to 30 feet up
# I've never bothered with 5e cause I dislike WotC
# other than just precise shot and stuff like that
# also have family coming for a bit but they should be here early so it shouldnt matter
# Zerotier is not ringing any bells
# already sent him this
# ghoul is pretty easy
# <@&868889886839689217> I'll be in call starting in 13 minutes
# Also this and Kingmaker <@&828644080443326494> need to get sorted out too
# Why cant I ping Lawrence and Randall
# <@589289513788899348> <@318536129727168512> ?
# Man we are loaded on damage
# So options for this week
# Which in most games doesn't have much effect
# I have asked if once Furic can do level 7 rituals, and if Furic learns the Awaken Animal ritual, i am playing a character whos an awakened squirrel rogue
# For wot
# what if I'm not doing either
# Off Mon -wed
# Up for either, work till mon, I get off sometime between 6-9 if you want a late session
# Hey so uh
# I have 4 sets of dice for everyone
# i see
# Randall's dub
# alright everyone grab a fortune effect
# Character: 15pt buy, Level 1 Commoner, Any core race
# Gear: 1 simple weapon you are proficent with, winter clothes, a backpack, 5gp of gear (+10gp if you have a profession or craft rank)
# Setting: The Crown of the World near the Rimethirst Mountains. Bonus human language is Erutaki.
#
# Gifts: The judge gifts one of the following to all gala attendents
# Holy Water:
# The Judge is quite superstitious and claims that this water can keep demons and evil spirits at bay .
# Thieves Tools:
# The judge personally swears that these are a must have for anyone who risks kidnapping or abduction. However, the local criminals seem to have better uses for them.
# Hide Shirt:
# Emblazoned with the holy symbol of Cayden Caliean this armor matches the patterns of the Judges Guards. Though it seems to be a lighter variety.
# Heavy Steel Shield:
# Adorned with a stylized rendition of Cayden Caliean's holy symbol this shield is identical to those carried by the Judge's guard.
# Ioun Torch:
# A floating stone that emits light in the surrounding. While certainly useful, it does make you stand out in a crowd.
# Any other day is cool
# That goes hand in hand with the civilization scale
# Or am I having a small moment of being stupid
# Piercings dragon
# Then I do whites every other week
# so how does wild magic work?
# ~~Well his character isnt here anyway rn~~
# Other occult may be stealing bronze dragons deal since conspirator reminds me of blue
# Unfortunately, Van is smart now.
# I look forward to seeing the edicts and anathemas of these dragons
# Fine with either
# Por que
# did that a few times last night
# The real question is does the whip work in 2e?
# not being turtles
# <@&927426307514581042> Tomorrow be there or be square
# Also Foundry will be up most of today is you guys wish to adjust characters
# It is only to people he considers enemies
# Yes, but...
# <@!318536129727168512> <@!318536129727168512> <@!318536129727168512> <@!318536129727168512> <@!318536129727168512>
# King tomorrow (Mon) <@318536129727168512> ?
# gandalf is a paladin
# Oh thats somewhat cool.
# Actually i might not today, my games stuttering a lot
# I think we started leanings towards getting eggs back after forge
# I support tristins plan
# No you each get point. I’ll just give Randall his a little early.
# remaster stuff coming to archives in next couple days in theory
# <@&927426307514581042> on the morrow
# holy shit
# Is there anywhere nearby he'd be interested in walking and/or biking to
# https://www.aonprd.com/MagicWeaponsDisplay.aspx?ItemName=Prying%20Star
# this sounds cool
# I forgot what the feature was called though
# with 1 trait
# TJ house, community college, fast food, park I guess
# works for me
# my dad mentioned valentines dinner so I might have to leave in a bit
# Which one you guys want to do? and will do the other tommorow
# yes it does
# I was making a joke that the world  would end when the orb hits 100%
# Yeah that's my point lmfao
# As long as what they are doing actually helps them Idrc
# the weapons are great too
# in the other westmarch rogue is by far the most played
# i forgot theres requirements, nvm
# he has 8 hit dice
# my classes gonna be funky
# <@&927426307514581042> In Zeds 1st shipment of goods the most notable item is:
# Wand of Magic Missile (1st) (23 of 50 charges) (345 gp)
# id say the only things that matched that difficulty spike were AT Nergigante at the end of World and Fatalis at the end of Iceborne
# If it were to be ok anyone i fell like it would be on me since I have experience with it
# That is on the fine line between a good and a terrible idea
# Smh no one else posting character pics
# Makes sense
# That makes sense... diabolic does imply devils are involved, rather than demons
# **Questionnaire to gauge Preferences (Anonymous)** 30xp to those who fill this out
# https://forms.gle/AAPxBrqBjVdAqiec9
# Still good feedback cause it lets me know none of them look boring lmao
# I saw people mention it was so... idk
# Gunna be able to spam more spells yeaaaaaaaa
# Frankly I think it's more a party comp issue than a luck issue
# Poke <@318536129727168512> ^
# I'm free Wednesday and Saturdays
# I am happy to once again be able to watch a video and use foundry
# he already got smite though
# idk maybe you do it
# Yeah lube up
# I work 11 to 7 on Sunday
# I rarely have a off
# I am not sure how cognizant I will be because I am doing a close and then open, but I will try my best
# "Every bard spell has a verbal component (song, recitation, or music)."
# I like to think my bard has a leitmotif in my inspire courage and my animate dead
# sunday will no work for me this week
# I would really appreciate it being easier to know what other monsters are enemies or allies
# Kingmakers been spoiled
# <@&828644080443326494> early sat into late sun
# Hey, I know this move
# Numbing tonic goes crazy
# Don't defend Randall's stupid
# really giving Kristen a hard time aint yall
# Beyond that only about 15% of each course is new information
# gimme 3-5 business days
# i work
# Ollie is going home to so scheduling is gonna suck
# cosmic allignment
# but the other thing about poppets
# Yep
# 10am-2pm sun
# We could move it up by 15 minutes and then by the time people have got downtime and such done it'd be about 30
# in theory  could i put noah in a backpack coup de grace the captain and steal his clothes and have noah mimic his voice for me
# The heck is struggle of the sacred tree?
# poppet definitely needs a once-over from paizo
# <@458413180893397022> before it comes up how will you rule this
# Also doesn’t really matter if it dies
# ive just never touched the safi
# Why in Kingmaker
# <@318536129727168512> Are you able to open up the Foundry for a minute?
# So now that I've got that out of the way
# The panache effect is so overkill
# Copy of foundry link
# <@&1064607664216231997> We'll just go with that
# Hedge cloak -> Rusty
# I think I'm good all those days
# Oliver dreams
# <@&828644223095275611> you guys still wan't to do something in person before school starts?
# thinking strength, agility, endurance, charm, insight
# Nah to both
# bro i know them for they hotdogs
# ima call em the hotdog people
# maybe drop int 2 and raise wis
# also my ac gunna be shit until i get some gold lol, i skipped out to save a little gold ill admit
# c is si
# Also wouldn't that mean than Native Americans where proto communist?
# Which is mildly problematic when it comes to being clever
# We’ll try for Tuesday or Wednesday I guess
# she is good at it
# <@458413180893397022>  :game_die:
# **Result**: 1d20 (3) + 9
# **Total**: 12
# not Nethys
# you cannot be an antipaladin of Nethys
# <@&828644080443326494> sunday late?
# Seems Mondays it is
# All I do is win
# https://paizo.com/community/blog
# Thinking along the lines of:
# You roll a nat 1 ->
# Roll another attack ->
# If the confirmation would hit resolve original as a normal attack ->
# If the confirmation would still miss then fumble
# and yes handler is obnoxious
# We buy a pet
# This is enlightened
# put a vampire under running water to kill it
# I can do it simpler than that
# You are the sus
# Correct
# Or deal with the Check penalty on atrack rolls
# I guess I can't really argue because I actually have Inventor Dedication
# You could do half-elf + adopted ancestry halfling + cultural adaptability gnome
# Cause I feel like killing Irovetti will likely do that
# May have to cancel/reschedule
# Ollie had a harder time than expected with this HW
# +they need some time to study for their midterms
# Makes more sense
# dont exist
# Friday perhaps
# cockroach but it can smite good
# crab added
# The kobold when crit rock
# Button to make dice go brrrr
# .
# Character level 10th | Mythic Tier 1st
# 25 point-buy
# 62,000 gp starting (+29,000gp for returning characters)
# Pvp is allowed, Evil alignments are permitted (both must be disclosed to me and approved as nondisruptive)
# The people of the Crown mainly speak Erutaki
#
# Returning Characters Note:
# The 29,000gp is in addition to the gold retrieved from Borgbreill’s tomb
# To restate the collected earnings from part 1:
# Tristin: 50,000gp, 10,000gp in wrecked magic items
# Everyone else: 4,000gp, 1,000gp in wrecked magic items
# @everyone React with ❄️ if interested
# What level your character
# Doin stuff for brothers Birthday
# what are some setting traits that are not related to amount of magic, amount of civilization, or time period
# So here's the conundrum I'm probably going to be closing most weekends this summer (including this weekend)
# which is close to good enough imo
# It was just a knife
# Was having a dream that had something to do with the pf witch class and woke up to a call from Winston Salem
# Tattooed orcs are lit
# Randall misunderstood what i said
# Finished one story mission. Gained two more.
# I mean all you need is 1 cargo crate
# all the remaster changes are in foundry btw
# Thesis statement
# Yea I was just looking at the songbird heritage of it, thought that'd be a funny bard. I can't seem to find the character rules on Ancestry and stuff so idk
# My time has come
# Would you let the magical knack trait counter the cl drops? https://aonprd.com/TraitDisplay.aspx?ItemName=Magical%20Knack
# ~~Next session is cancelled btw~~
# I will be running Foundry during normal time if you guys want to work on putting your characters in
# Don't forget to level up
# but might wanna put the foundry up so we can level our characters
# Well yeah but barbarians just
# I didnt prep it
# And I'll be retraining to get a giant crab mount soon
# My character would have to exist to do so
# right now for some monsters you have to comb through a description and the wiki to get a good feel
# he has an idea
# It took me a second but I looked at the word Roman a couple times, physically held up 2 fingers then got it
# das not a room
# Oh I get it now
# Thats my characters immediate family
# Rip Gorgar the 1st though
# Gotta set up the whirlwind throw loop
# i should be there <@!151489352164311040>
# No actually lmao
# Fair enough
# I should just be a minute or 2 late but they might run long
# Can Kingmaker 2 see it?
# but um, i cant say it'll change much
# What is even the point of the Sage Animist?
# After next session Justin can go to the caverns
# In all honesty I play sns, gs, Lance, and dual blades
# I like it better
# I will be grinding from now until they are over 😔
# wdym i havent had
# Wait is that Empyreal?
# @everyone down for tonight?
# That one you sent has invis as a spell-like 1/day which is a big hmm
# Crab is good
# steam knight seems fun to use
# His Aura
# As a note to people who dont know we did find an aeon stone shop
# No I knew you were referring to the undead I just was thinking back to normal undead sessions
# Plus like... I enjoy summoner and I always challenge daytime empress for her terraprisma and no way in hell am I doing that in one try.
# 2 or 3
# There actually isn't a penalty to using a fervent weapon of a different religion so
# Dark-ness
# Locked away
# Lirgen kings chose us to pay
# I was tempted to pick barbarian
# But going ranger lets me attack a bunch with effectively no penalty
# When gome?
# Cool Math
# i do
# i added mario kart for the ds doh
# You have lived in them
# I have been told it is but this is the first time actually seeing it
# <@589289513788899348>
# <@318536129727168512>
# Shaking my glock
# given they can use it as a fucking *cannon*
# might go lay down
# Yeah in the crpg the mythic classes are more creature based Angel, Demon, Dragon, etc
#
# The Ap has mythic paths based on character achetypes Archmage, Trickster etc
# 6 hour long dual session
# also good for saturday early but my uncle is still in town so i may be taken
# Sorry about that
# I like all of the mythological references in the Exemplar abilities
# Do tiny and smaller creatures still have a 5 foot step
# I'll ask off for the 25th
# 5 good
# what else would i do
# Yeah cause no character can match the swagger of Cayden
# They are now eastern kobolds /s
# Having some mecha can food
# I have put too much time into a certain map
# but we'll have to wait for aon to get updated
# Does that == gestalt
# Sí Sí
# Meant which AP
# Ided by Ollie
# I guess I wasn't there today
# Echo prep shuffle
# The normal feat has no reason for you to take it over dodge
# What about ya'll?
# That's true
# Bad news guys zombies are in fact not wholsome 100
# I think the play is getting as many attacks as you can in a turn prioritizing damage over attack. And don't use companions unless they are immune to spirit damage
# i think vamps should have regen
# I can craft that now lmao
# I see
# Making tristin call me asinine is entertaining
# It isn't that he's literally "living" he's just treated as one for effects cause he lacks immunities or something dumb like that
# I'm positive if I had started walking when I first drove down and realized I couldn't leave It still would have been faster to just wait and then drive
# Okay next week I have like Monday Thurs off
# the gym was sorta a dick move
# https://aonprd.com/Rules.aspx?Name=Free%20Actions&Category=Action%20Types
# Core rule book description
# Time to remember how my character worked
# shadow wizard money gang 🤙
# <@&828644223095275611> <@&828644080443326494> maybe today 🤔
# You aight noah
# <@&828644080443326494> 40 min
# Yeah not Duergar
# Hey can ya'll go through the stuff in gnome hoard and tell me what ya'll took, what ya'll left with Zed, and what ya'll trashed
# If you cannot tell then you are not a master of the game
# Dusty rose cracked prism is cheap as hell
# leave the best stats for last
# And how you spell Bovian Kings name?
# I think humanoid is supposed to be a biology thing less than a shape thing
# fyi kingmaker 2 is wednesday at 8
# I would be down for an alchemist crow though. But i feel like he wouldn't be able to carry jackshit without being over carry weight.
# you have not found out
# Better for oracle
# But I doubt you plan on finessing anything so
# i will join when law shows
# Oh shit yeah I gotta do all that foundry stuff
# interesting word choice
# I've also been into the dorms to visit people
# <@&828644080443326494> 1 hour
# <@&1020589184437714995> it has been done
# a fire-water kineticist would be neat
# i thought that was so dumb
# That plus endurance would cancel it out completely
# stopping right before wildspire
# I guess I should maybe not make this character in that case
# Natural Spell is a sick feat for a druid btw
# <@458413180893397022> hopefully I'll see you again fall 2022
# what you mean
# Finding my boat
# And be open to things other than FAIRY GODPARENTS
# Oh. Now I feel dumb. Perhaps I'm low on sleep lol
# What happened to armag
# play a sturdy skeleton
# You guys have fun...
# Btw you guys all gained a hero point when you leveled up
# Things that are not organic or full angels and shit are a different thing
# Def not Wednesday cuz early time
# NPC can clean up a little and be fine
# If you played in Struggle for the Sacred Tree, Trial of the Kobold King, Caravan's Gambit, or Sunfire Citadel you got a one shot box.
# young anyways
# pretty sure you lose your tail in beast shape
# TJ gonna need paint cause his ass is blue
# oh ok
# Imagine not being in Raleigh
# Anyways I would like to try and get everyone in a call for like 15 minutes today so I can communicate the last parts of book 1.
# was guessing it was you
# Okay so I guess Ill start planing around when I get my schedule
# Ah i forgor, you decided to make you poverty a personality trait
# I called it jelly
# Ups all his shit
# on that working man grind
# I was assuming we were doing monday
# He thought there was no gnome because he thought I was busy when I was not busy
# So we should be good to run both next week and the week after <@&927426307514581042>
# Sorry for my brain damage
# Hmm wb Mon or Tues then
# Though If I rise and grind tonight I could prob run it tomorrow?
# Also idk why you think flight is so important
# 630 maybe?
# other races do though
# Lmao
# Nah Nethys dying would be boring
# "I killed the god of magic" is overdone
# For the same reason I think Gorum is safe
# also i can give it 5 foot reach for some reason
# You know I think min making umd is the progamer move to fix my spell troubles
# 25 damage on golem
# Try being jobless /s
# On a similar note we might want to redefine our session times
# 18 21 18 4 15 13
# Yall good for tues
# I don't think I do
# The local Necromancer
# Theres a halfling only feat that is power attack but better
# After 5:30pm mon - thurs and all day sat-sun
# Yeah I can
# The champion is still cracked
# Cant do Saturday doin birthday stuff but Sun good
# I mean you would be full bab if the dmg bonus is that high at lvl 4
# Campaign Interests
# fair. man
# <@!458413180893397022> can only use it once per day though
# Hey <@318536129727168512> can I attempt a craft alchemy check to collect ghost salt from ash mans remains
# Maybe they are gonna release an Ap with some time travel chicanery
# Basically, I know that im just pulling dick moves but at the same time, i have the freedom to be busy and/or "busy" elsewhere
# The first one I'm concerned about the the second one I know is fine I'm just curious who it is
# But that's only if all the members are fine with it because idk if it'll work well
# 2nd thing I have no car + my mom will be at work so I can't get her to bring me
# Graduation stuff
# <@&927426307514581042> Saturday @5?
# Close rest of week
# Was unsure what the timeline of these one shots really looks like in conparison to each other
# Werebat-kin don’t have a tail initially
# The table play was the real mvp
# ok red gulpiegator
# also lance charge
# ||Not if I'm the DM||
# unless they're racist towards darker skinned humans too
# *don't have decent sized tables
# I have no idea
# Tristin rn
# there is a decent chance lawrence will be at the gym
# That'll make creating my level 20 one shot character easier
# So great time to redo WotR
# Cuz I swear at the end of whatever it was  you were like oh yeah you leveled up
# Seems accurate
# <@589289513788899348>  <@492768651389435909><@146626274066956288>?
# Skeleton Champion cohort sounds pog
# Hey if possible can we do the one shot tomorrow I had just gotten home from work and now need to deal with some shit if not it’s ok feel free to run it I’m sorry
# Gonna go kill Fatalis real quick, I'll get back to you all in 3 weeks
# When are we trying to do Pathfinder this week?
# such a fun fight
# That will apply for enemies as well as you guys
# If anyone has suggestions let me know. This is subject to change
# I meant for sans
# An optional form for those who don't want to "write" a character backstory or need inspiration
# https://forms.gle/x4uGw8dTVypNyH2k7
# <@&828644080443326494> if you aren't don't forget to level up to 7th.
# Hedge Cloak
# <@146626274066956288>  :game_die:
# **Result**: 1d20 (17)
# **Total**: 17
# and then just die in a method of your choosing
# Gotcha
# Read the harness rules and couldnt tell
# Cause it has the same permissions as the other one shots
# will be taken sunday@7
# unfortunately skeletons can't become ghouls
# we each make wrestling characters and do a tournament
# That’s Father’s Day
# Ik I have Sundays off
# I stopped playing after this event, if that gives you context
# then just sunday
# the summon level increases every 2 levels
# My favorite
# That one is basically undead
# <@&927426307514581042> Does Sat or Sun at 6 work for ya'll
# like magical girls lmao
# it was at 8
# I don't think many people are waiting on it. I'd rather make something people'd enjoy then go further.
# but deadass hyped for those classes
# I am going to assume prop not until full release?
# add that to the end of tris
# Ah makes sense.
# a Man? more like CEO of not being 18
# I think they are good
# They took a minute today
# Bro you know what I mean
# Guilds/Businesses and Dungeons
# as you do
# Or from star quad… it echoes it real good around there
# I get that, I'm honestly treating it more akin to a rouge like
# Ah gotcha
# i went insane right
# Or
# Huge enemies
# <@378709482953244672> you still interested?
# Final boss
# i guess
# Tristin has a module for it in pathbuilder and foundry pinned in 2e resources
# He hasn’t done anything. Yet.
# Gunlance my beloved
# <@151489352164311040> one of those says somepony
# I still don't know why Sage is a thing
# So not this week hours
# If I catch the car on fire we can push it back by 15
# Smh the idea is you pick it when you take the trait lmao
# Cause rn from what Ive gathered they are
# An undead creature, treated as living, and have selective undead benefits
# Unless somebody hits you with a remove curse spell
# He didn’t get spells this level
# i hav to go back to careday at 4
# i cant carry out what i put in your yearbook
# unsure. Maybe immediately if I have reloading.
# My desktop discord has something where I get combo for each letter I type
# <@!146626274066956288> you want me to drop you from wotw? Like legitimate question cause you don't seem to want to play
# Hey when yall free for this
# I’m good
# What did you end up using
# invasion of privacy bad but....
# Custom kobold bloodlines time
# <@456226577798135808> Good luck with your campaign!
# Yeah me and Fable both realize that our responses prob weren't confirmation enough
# I accepted it
# We are fucked
# But I mean hey
# Play gnome or go home
# answer question ples
# abstract or cliques
# and get pretty much anything to 4 ancestries
# 3rd level all his cure spells are empowered on himself
# I may need to go through and just universally increase numbers
# I know
# All 4 of them are cracking me up
# unfortunately
# aon is shitting its pants for me atm
# I am in a word game with Law but will join when others do assuming we are still on
# ya know it
# Are maces simple or martial?
# I updated to v11
# wait so in way of the wicked can noah mount me
# e dluohs w
# Enemy Hammer?
# That is true
# This dryer us giving me society moments
# Yeah thats how I've always used ruler
# Didn't know about the right click pop out
# Unless we have a good reason to go anywhere else east sound like the way to go
# I guess
# Okay when do you not
# either should work
# Cause work wasn’t mentioned
# pretty cool video
# we work at the same time
# i can ask for that day off
# Like I said I don't really have the idea for the one shot yet I just know I want to do one that gives people some idea of how archetype works
# I just realised that its possible to be an antipaladin of irori
# Yeah but they undid that so we chill
# max speed gestalt build
# Oh I just saw this
# You prob renames gaseous cloud
# When 😔
# Although it’s possible I get pulled away by parents
# What was the buy price in blackwater
# Fuck off mate
# Lets try and start at like 2:30 tomorrow then
# Adaptive Anadi does specify common ancestry
# I will be home in about 10 minutes
# PLot isn't the hard part
# https://www.d20pfsrd.com/gamemastering/other-rules/downtime/rooms-and-teams/ this gives prices on setting up different rooms and also ideas for stuff you guys could add
# 3. Lord Havelyn is a good soul but so grim and
# gloomy. For so great a lord to be unhappy, he
# must be guilty about something!
# im free for once
# Cant going to greenboro
# and i already have a patron , his name is asmodeus
# I do not have a practical application for this but making an entire suit of armor from some stuff you have laying around is funny
# I might need a second token for the Eidolon
# If you can send me like a magic item crafting order I can cover that for the time you aren't there
# Do Aasimars not have a racial penalty?
# too much significant shit happened last session
# just asking cause other game slot just opened
# They're considered slings unfortunately
# I mean generally I feel you can get a good feel for monster tactics from theirs stats/abilities
# Wait fuck
# Shit sorry
# That's actually really cool
# <@&828644080443326494> we dropping Randall?
# and could only be cured through high level magic
# They should basically be
# So does 26 sound right for 4d8+8
# Be a werebat-kin, take bat shape to turn into a tiny bat, take mischievous and grasping tail so you tail counts as a hand for all purpose, and finally become an air kineticist so you can be a tiny bat who summons lightning and hurricanes with your tail
# Free sun
# 15. Lord Thomas Havelyn is the most honorable and
# capable commander that Balentyne has ever had.
# If he can’t keep the Watch Wall working, then no
# one can!
# With that and the foundry being updated I will now remove the [remaster] rules
# Were you the one with the jellyfish
# I mean Erastil and Urgotha werent obviously safe
# I am free tommorow and I open Sunday so I am free then
# we ended
# I need to level up rat tmk
# foundry is up btw
# +3 at level 1 cause level + 2
# And blind sight lets you see through walls and shit too
# This Sunday not free
# Alan's creek
# it'll prob be up for the rest of the day
# hows it going
# Champion looks like Cavalier + Paladin
# Fair but that feels like a different kind of limitation that rules lawyers will take to seriously
# I like the unlimited wealth cause I'm imagining it buying a giant mech suit and hunting you down
# I like Enemy Hammer more
# Considering retraining my Witch archetype into Magus
# ie does wearing full plate allow you to go out during the day as long as you're fully suited up and never remove it
# Which could be funny
# I concur
# Yeah but from what I've gathered Furic would have been a valid target for the siphon but his bird wouldn't
# but it works off the base system and needs the handwraps to put the runes on
# Technical difficulties
# The +4 is the funny part
# the problem isnt finding tieflings
# Oh right
# I think the undead trait may have got redefined in the remaster and/or will in monster core
# Oli doesn't know who I am
# im sure theres a way
# what else do?
# I am
# Oh shit
# you know something like this minus the guns lmao
# They came from Bovia
# May need to help my uncle move though
# I’m good with whatever anyone wants to use
# Huh, didnt notice that
# If we go to the capital the buy price may be high enough for fervent though
# Even if I wasnt my desktop went to sleep somehow so no foundry
# The oracle could prob catch some if he has a rank in survival
# But yeah is they weren't a living creature they technically couldn't even be targeted with it
# Is normal time 4 or 5?
# So is this a all level 1 mission
# <@151489352164311040> in particular
# i will never play that because i know id get the 25% 100% of the time
# Fair (doesen't hurt to have it in more places)
# I see
# The only correct answer lmao
# I do
# No restrictions on rare ancestries
# Uncommon ancestry + versatile heritage is fine
# Run rare ancestry + versatile heritage by me
# <@318536129727168512>  normal time Saturday and early time Sunday again?
# or would i even be allowed
# of course i have
# Counterpoint, go door to door advertising to every dorm room
# Nah it’s next Monday and Tuesday
# I might need to re-make my character o.o
# it understands common so we can go through the alphabet and tell it to bark when we get to the right letter
# For if anyone wants to discuss anything they are working on or anything like that
# btw something the book said gives me the idea that you are only supposed to have one background trait
# No I'm saying I have to level both kingmaker characters and complete various stat blocks for wotw
# you guys could be evil in the gestalt ap if you were so inclined
# That's why I'm wondering Gozreh
# <@151500793990742016> <@589289513788899348>  Gnoming time
# I've added bonus xp for those who fill out the above form and those who give me a background (whether through the background form or otherwise)
# From what I can tell most games have that stipulation
# 1 down 2 to go
# Wunna recreate my poor character from my last try at starfinder 1e, man with biggest gun he could find
# If I go for anything above a bachelor's, I defenitely won't be doing both
# I'm totally fine when it comes to your mom giving you stuff to do
# I go in at 4
# good show
# Yeah but you lack a Con
# Personally I think youd get your Cha to it twice
# But it does have a timeline I think cause Vordekai and Armag
# So hear me out what if Law works on his oneshot character
# But it's on the list for party comp so I assume it is allowed
# I should be free weekend
# Should be good for both
# i think you'll find the level 1 rogue has very enlighteneing ideals surrounding his place in the world
# Actually nvm seems no such spell exists
# Soul Siphon, I think
# Such as right now
# My brain went "you guys can't drink" for a second
# That's so fair
# This assignment was gonna be for beginners (so basic classes)
# Though is people want guides for classes I'd be happy to make them
# yeah it was me and randall
# like there have already been things you've seen
# should we
# Trying to make that damn cellphone
# you are going to edge
# I prob can
# Me 😔
# 5 good for yall
# Mother won't stfu
# oooh thats a nice feat
# I have a car bomb to deactivate <@589289513788899348>
# Works for me
# I'm sure in-city stuff is somewhat planned and Tristan is simply going along with what people ask for. Which so far isn't in the cities
# That works
# Yeah but it isnt your prehensile one
# and weekend I assume TJ
# There may be some pve type stuff but mainly pvp
# i wanna do kingmaker tonight
# Ah
# Paladin moment with  goated 5th level saves
# charcter idea
# do something with this
# Yeah I mean on Sun
# Makes sense
# apparently that list was in the player core
# It gets significantly better at level 2
# Splendid thank you
# ||I'm not home so||...
# My work closed
# Dire frog
# Which is a really weird gap in the rules
# Will in fact be late
# <@!151500793990742016>  :game_die:
# **Result**: 1d20 (6)
# **Total**: 6
# At Zax
# Dc is still 20 lol
# Basically same situation once again
# Replacing lowes with the attic
# even <:wah:951310823366754334>
# I meant the 2 dragon types
# +4d6 to every attack
# You eight
# I could do Sunday I think
# so I need a backstory by then
# Who up finding their path?
# I *Could* make a character as strong as a normal character
# I vote kingmaker
# Randall looked at me confused and said
# I don't have a day that I'm typically off
# how do we know when we hit the last letter though
# Nethys makes sense
# Yeah thats the obvious RAI
# I cannot
# mmm i see
# @everyone 10 min
# or pay someone to mummify you
# Is everyone still good for 5? <@&927426307514581042> Or does it need to be pushed to 6
# Ultimate Vindication (Ex): At 20th level, if a foe kills one of a vindictive bastard’s allies or knocks the vindictive bastard unconscious (and she later regains consciousness), the vindictive bastard musters a vindictive fury. The next time she hits that foe within 1 minute, the vindictive bastard can channel the effects of a disintegrate spell through her weapon, using her paladin level as her effective caster level. Whether or not the target succeeds at its save against the disintegrate effect, it is immune to this ability for the next 24 hours.
# and flavor the rest of the character
# thats good
# wtf is this
# What are you guys thoughts on using this system?
# and then like 50 or 100 becomes very easy and then like 1000 is incredibly easy
# I did not think about that
# are you ton or ten
# Why the fuck didn't you send the days then as well
# Not that I can recall off the top of my head
# Yeah I can
# lemme get my mic
# Why are you up at 2am on a Monday?
# Was planning Wolf Sun
# Playing a charisma trickster:
# +the game is pretty popular so
# Tbf Goku would be in a hot minute
# Cause ngl
# Making meme enemies is hella boring
# ladies and gentleman
# How does the tiger not suffocate?
# If you right click a tab it does the pop out tab
# Like at 6
# i will spread the good word of cheap mhw
# Yeah 6
# thank you
# It’s the circle of death
# I think it was a good idea
# Starts with "if the user meets"
# https://www.aonprd.com/Rules.aspx?Name=Scrolls&Category=Magic%20Items
# Now it's at 11:40
# Send them straight to Brazil
# hotdog is simply superior
# Was trying to be haha funny
# Or rusty
# Ruff even
# but you have the same roles as Connor so idk
# sounds good
# They still wont like you as much as human
# Kool Aid man build
# Okay Sunday then
# Cause bloodline didnt change spell type in 1e
# bed cozy zzzzzz
# If it makes sense character wise then it will be the most likely
# No pathfinder today. I gotta meet up with a cousin for pictures.
# Makes sense
# fun fact. For reasons. All of the gods on Agrios (this setting) are weaker than most Golarion gods.
# Ya'll still up for a (prob shorter) session?
# And 3 for period
# I also see that
# mfw one of my characters is already a multiclass
# I cpuld have sworn on my life they did
# so its hard to research
# Sorry I had to disappear last minute Mom was getting cranky cause I was lettimg my dinner get cold
# Good to know
# so is randall
# I could do 5 on the morrow
# So pizza sound good to everyone (except TJ)
# Nah thats kinda mid
# But it's aimed at rouges anyway
# Hey <@146626274066956288> is it you actually
# also ghouls are more like vampires now which I like
# They look like the protags of the story lol
# Well then I guess I’m race swapping
# multiple ways to get cha to dodge
# Unlike anything else immune to bleed (like constructs)
# which one do you not want to run
# Also how does uc barb temp hp work with wounds
# Hey how do yall feel about trying a house rule of confirming fumbles? Instead of an auto AOO?
# Add to list in <#872558532719960115>
# I mean
# Damnit I knew Id miss at least 1 effect that'd insta kill him
# Like Kingmaker got
# currently working on a lower magic system for a hunger games type rpg
# There isn't very much art for desert giants
# so no
# and I can see them when looking here
# only took 2 hours
# Btw i cant do gnome this Tuesday
# I have a physics test that night
# Free for good or free to try
# I'm free whenever except for Saturday
# Well at least I don't have to go on a tiefling hunt in the country with no tieflings
# so no he||als||
# <@&828644080443326494> Saturday Monday early
# dude were off for MLK day sob
# Hey guys dont forget you +1 a stat every 4 lvls as normal
# Change my mind
# This is the best feat it the game:
# https://www.aonprd.com/FeatDisplay.aspx?ItemName=Stunning%20Irruption
# Jumpstart was fun
# <@&828644223095275611> <@&828644080443326494> Saturday 6 and Sunday early. I’m down for with campaign since last wotw session was pretty light.
# 6 should be good
# and those can change every time they're channeled
# In 1e a large creature could use a cannon like a gun
# Look I wasn't seeing enough schmoovment
# And I have the art I used for him
# hehehey new mexico go brrr
#
# anyways i can do anything past maybe the 1st, 5th would be most convenient
# Anyone dead yet?
# aka probably
# what if we all crit succeed all the saves
# so does pathfinder exist today?
# not as good looking as great jagras
# but from my first look at the ikons
# i would not call them internally balanced
# 30 mins
# Infected tooth
# Okay so basically they're a consumable?
# +10 damage at lvl 4
# I won't disagree, but it's because I hadn't seen the rest of the message yet
# This was in reference to what Noah said just so u kno
# Gaé Bulg?
# If you just hold control and drag click it uses the ruler tool
# 6:30 would be the start time
# Or is that for you to know and us to find out
# The 1e prep agony
# But at the same time how much i pay attention in total leaves a little to be desired
# theres a 9% monkass
# Not in wotw
# i can
# Is it +2 to 2 minus 2 to any?
# Hey guys could I borrow some money next time we are in town?
# Dont worry there are no grapplers...
# I'd be down for 6 imo
# Can rusty use wands?
# Like 6 or 6:30
# Aight its Gnomin' time
# ~~Unless people want me to push it back some~~
# Yeah. Spell level dc + 5
# Use soul gems to craft magic items sounds better
# Rome roaming inspired me
# For both
# All males will now have to roll 1d8 for dick size
# i EXIST
# What does it cost to make a tiny bag of holding or equivalent tool that furic could give to awakened little animals to let em have normal inventories
# <@!146626274066956288>  :game_die:
# **Result**: 1d20 (7) + 11
# **Total**: 18
# <@589289513788899348> <@456034448194928641> <@458413180893397022>
# May also wanna do the jaw thing cause you could add eyes as something to target
# <@531348109347782656>  :game_die:
# **Result**: 2d8 (3, 4)
# **Total**: 7
# I'll pick this back up tomorrow when the crowd is better rested
# I mean its fine
# I just didnt realize we were on
# (I have procrastinated map making)
# Should be good
# You can thank the star god for that
# So what you are saying is that there is a seige going on
# im looking at a familiar archtype that lets you take
#  evolutions
# I understand
# you could also go around throwing yourself at vampires asking to be bitten
# <@&927426307514581042> you know
# I mean sylphs are pretty neat
# Mans gonna hit em with the Marth down tilt
# idk bout tommorow but should be good for the weekend
# Just to make sure Ive preped correctly you guys are planning on finishing the forge this session?
# I'm not exactly sure how I'd get immunity to mental and auditory effects, but I'll try
# reincarnation and amnesia should be added
# Sounds like a plan
# Kineticist only need a free prehensile appendage
# I'll use one
# AT Nergigante was honestly peak World
# Since main group is dead
# Actually more like 2.5
# Is it like 8 hours total with a 1 hour break?
# I couldn't tell you why
# In which case I still do not have access but it is for a very different reason
# Did they replace it?
# As a 2nd level power attack fighter
# I just remembered the club I was planning on attending meets friday after 5
# Neck is too short
# well thats why im pulling you fuckers back into it
# I will probably skip through travel a bit more in the future or at least make it brief and leave some of the other stuff for sessions focused on that or rp chat.
# I think this is how you make a deity
# Brightblade's Bravo:
# 3/day as an immediate action replace a save with Fort + demoralize enemies who witness
#
# <@151489352164311040> Was a sample I had for you
# How Templates will work
# 1. A template will take a number of levels equal to the CR bonus
# 2. You will gain the abilities over the span of these levels
# 3. These abilities will be divided up so you get a similar amount of stuff each level
# 4. You will get a hit dice for each level equal to your most common hit dice
# 5. Casters will gain +1 Level of spell casting after the first level in a template
# It is basically going to be like a mini prestige class
# Like he knows his suit and ocean shit... and that's it?
# I like reading the troll page and then reading his
# Okay I’ve finally decided on my build
# can do! ill rush up and finish the character
# I think the brevoy part is the main thing strapping it down
# Character Portraits
# Honestly I think the level spread should be capped at 2
# Cause being the low level in those session sucks, even if you get more xp for it
# Also can feel like you get diffed when you schedule a session and the party is all higher than you
# everyone is just a fighter
# I just haven't existed it
# Banish them
# Its only 5 if you aren't slow
# i concur
# from a bank or from us
# ignore the firey hair
# bruh i forgot the snake existed
# Idk if you could stack those since it would have to be Mitra attuned
# Both early
# I got it covered
# My face when 2e has no Paladin class
# tristin really just disregarded fables idea <:smh:744345376525516861>
# I like the lingering composition feat
# im ngl tho that 1 hour break was just nice
# Monday, Tuesday, and Wednesday work best for me
# ah im balls deep in cp
# it just had some oversight
# exemplar feats have some true anime bullshit names
# 2/5 said they couldnt come so if one more dips then we can do it
# I pulled a big stupid and slept at like 6pm
# but it is painful
# magic or no magic
# I feel like there should be a way 2e kin can do void
# You get to break the action economy at level 1
# or got discord banned
# I'm down if others are
# But whats his stealth
# Btw note on that Kobold those guys had him like that for 2ish weeks
# Idk about Monday
# no clases friday <:shrug:858187229779460116>
# No sf1e was like half way between 1e and 2e pf
# Can you not hear us?
# Randall does
# I would be down
# 2 questions
# Will you be tiny
# Will you have a fly speed
# Fable working until Monday
# I feel like it
# Its 4/1
# Monk only party
# I like killing people in the past personally lmfao
# If I am activley eating a meal it is usally 15 min
# then i guess ill miss
# Yeh thats a good option
# you dont want the whole gestalt ap to be a dream?
# Im good all the way through Thursday
# the - is negitive
# Boys! The plan is grimple
# Light has been rrstored to my lair
# I grabbed remove curse
# can you just
# bro up to something
# 120ft tremorsense
# uh oh
# also mauler dedication
# "I like money"
# "I dislike not having your money"
# O fuck I forgot about this
# Tj might be fine honestly
# rock bitch
# So maybe it would make sense for those two to be in opposition
# and/or others are in town
# 1.5 miles
# raven that sits on a tree and pretends to be a Funny demon worshiping tree
# Or telekinetic fox
# What was the last thing we did
# so in theory i could give a spider and a bow
# O god
# lance gang
# <@&927426307514581042> Today at 6 or tomorrow at 5?
# Where do y'all meet, what time
# I said my unavailability in general because I was gunna bring up getting a puppy that's gunna chew everything in sight, but it very quickly just became scheduling lol
# So traps. Gotcha
# Wait what level are we in King
# We will now get stuff like the dragons and prophecies automatically
# We're allowed to take two archetypes at level 2, right?
# And Brevoy in general
# agree :)
# Do we have Pathfinder today
# Is that a 1e ap
# from what im reading
# that isn't one of the things listed in basic undead benefits
# I'm at dentist
# <@151489352164311040> <@492768651389435909> <@589289513788899348> <@531348109347782656> would you care if I had a homebrew race if it was balanced
# Added details about the local humanlanguage
# Is there a chef or cook archetype?
# Spell-likes are spells
# They get those as (Su)s?
# o ic
# Through the power of friendship, your familiar becomes a valid target for Awaken Animal
# I see you added the dash delta bot
# Im not sure if I described this well but both sides at Zeds were fully entrenched
# i know not what you refer to
# rip tris
# Is there any news on starfinder 2e?
# Then I guess we aren't playing again this week\
# Oh yeah cause you're level 4 now
# I also might want to make this guy a fighter instead
# Then I'm thinking the 20th at 5:30?
# Though this is the anniversary so a certain group of enemies got nerfed
# it is what i have been doing
# I'll brb
# Technically none of this is real
# Allergy medicine consumed, omw home
# Oh shit
# or monastic archery
# I think I'm gonna introduce a turtle race in the homebrew
# No kingmaker was last. You guys about to raid fort shits
# Grumblejack has gained the service of a Worg that will likely be out of combat (cause racial hit dice make it severally under leveled)
# Hey <@&981382306663120919> does the 29th work for everyone
# what does this mean
# 8.5 hours
# I am
# I think the plan was
# Go back to kobolds
# Go talk to gripplis
# Go south and get horse for paladin
# Go to other grippli place
# Go see if we can find Oliver mom
# i just tend to never make second characters
# Supposedly build computer today
# I got it on accident
# Time for **reach spell**
# Gotta play genetics
# SMite and bane stack I'm pretty sure
# I don’t work Wednesday
# Good question
# swashbuckler rat would save the day
# Lmao I think you have to have +5 bab before you can even take bat shape
# You fool now I want to construct a thieves guild in my room
# Trust me it'll be funny
# I disregarded fables roll cause we needed high or low before the roll
# I thought you meant that feat
# new update is cool ngl
# Majority of his spells are bonus spells
# Uh, I don't mind either but new kingmaker book is enticing
# +4 to jumping for every 10 above 30
# also this may be the first evidence I have personally seen of adamantine being black
# figured something out
# Was just hoping to get it like marshal where a thing pops up asking you which you want
# one moment
# It's a *Metagame Artifact*
# And with my family
# i put many many hours into that
# Its actually higher for a good result
# Black night was Enidor
# Girl was from Datarus?
# Do Mirage and Fortune counteract eachother in that way?
# short too
# I'll write you a summary Randall
# Van Karthy aquatic adventure when
# Hey ya'll I'm going to have to miss this weekend to deal with family matters in the aftermath of my father's death. I'm currently in Stoneville, NC at my grandparents with little to no service. I'm fine with everyone in this chat knowing why I'm busy this weekend but please keep it to yourselves.
# Alright TJ and Randall said yes
# my b
# oh yeah
# Didn't tj choose one
# yeah i know that
# I think
# My problem is when you and J plan on going to the gym and you don't tell me until the game has started and we are asking where you are
# Personally I would be fine with it, more orcs the merrier
# Probably not tonight unless UNCC cancels
# I'm good either way. Seems like for Fable sake it'd be simpler to do gnome.
# Fyi there is a turtle race in dnd if you need a base
# Probably not I have to get homework and other stuff done today
# Including Pathfinder 2e
# btw nothing says life link is positive energy so it should work on undead
# beware the summoning
# In general its just fanatical takes less of a cut then steam so devs charge less
# Does if it isn’t Mortimer
# Over the past few months I've been trying to do a hardcore run, not getting very far cause I'm playing much to risky
# Seems useful
# oh shit nvm
# Fire bitch is gone
# prolly free for good
# ill come back to you
# At work?
# Ima make tristin my favored enemy
# i can't do monday from 2:30-8:45 or so so sunday is the only day i can really make this week
# My gpu is having a stroke
# <@&828644080443326494> 20 min
# But thats only for me
# Duality of man
# after 5 sure
# It just pays alot
# ...
# Great Jagras is dead. Which means the handler is the only fatass remaining who id like to remove from the local area
# But I'd have to restart.... hmmmm
# Nah the new thing is way cooler
# So Monday early
# I'll change it to Maimed then
# I wait longer to be able to be a wizard with a shield
# That'll probably be okay. Do you know how long?
# My computer would not work well in a void
# savvy is nice sounding
# <@!151500793990742016> ^
# 3 reports + 80 from background and form wouldn't be enough to get you to 2
# Yeah I know
# It always drops to 1 is so funny to me
# I also used to be able to see wasteland but that is now banished as well I presume
# i saw closed s day, my brain edited out the un so i skipped over that sig
# New idea, Kitsune (with fox shape, and the tail feats again), soulbound summoner unchained, get the deaf oracle curse so you have constant silent spell and you can use your tail for somatic components, and your eidolon can be an Ancestor so it has the Kitsune change shape racial trait and can appear as human (or a different eidolon subtype and cast alter self on it). Also, take that feat that lets you hide your spell casting with a bluff check. Now you can pretend to be a pet fox, wag your tail to cast a spell then hide it with a bluff check, and even though you're deaf you can still essentially hear because you have the eidolon link ability which is essentially telepathy with your eidolon so it can just tell you what's going on/what's being said
# but you may have found a piece im missing
# 1. Have you ever been to the choir hall of Balentyne?
# Amazing! The priests are such beautiful singers
# and sometimes the stone saints that adorn the
# place join in the chorus. Such a miracle!
# which one we doin
# Over 1.5k hours
# I didn’t want it to be too choreographed incase you guys wanted to step in
# smh don't reveal company secrets
# I was thinking of closet as in like a group of people
# Question are old age penalties in 2e?
# based honestly
# But his body is not good
# Lunge + big + sarissa = ranged attacks
# i just did my actions and that was all
# I need it for political reasons
# He'll take it then
# Oh 100%
# But just thought I'd mention the weird shit
# Thats why Echos got pushed so far back
# Minotaur: 6hd
# Wrath was?
# right now there is a session being planned to help a farmer with a delivery to a shrine
# Prolly tho I forgot I have my dmv appointment then as well but I doubt it'll be after 5
# a couple minutes ago
# What would he get retrained as?
# Him being an Inquisitor could be sick
# he just cant type on his phone atm
# Wait I thought they could be clerics
# oh yo sure!!
# Can't talk to women confirmed
# I planned to mitigate some of those but I guess their will always some. idk if I want to continue at this point
# i think
# This is a platypus skeleton. That is a disfigured fetus.
# But I'm ok
# overwatch at 8
# "Ah yes let me pull all the ingredients in the world out of my inventory"
# Said it a couple times
# i literally am unable to say no
# we had time
# that's ok!
# okay yeah
# Okay so a couple small things
# Where tf does Lawrence live
# Yea I need to learn type 1 and give it to awakened animals anyone plays lol
# There is no specifically desert giant heritage but goliath and maybe fire fit the bill
# What should stats be?
# and by that i mena noah
# <@458413180893397022> you alright?
# So no more dropping weapons as a free action lol
# Fair changes
# Meant react lmao
# i would help you with the homebrew thing since i love a good story but i dont wanna spoil it for myself
# cuz ged is so easy
# They have already said that isnt all ikons especially since unarmed strike isnt covered
# would saturday work?
# I definitely did not do all four
# gun lance gang
# that was on my mind
# They were in my mind
# ROWDY PETE WILL NEVER SEE THE CONSEQUENCES OF HIS ACTIONS
# like 5 for now and then may open it later
# Cant so youre good to
# Nah dont be like that man, ill admit i was a little harsh. But I mean if you got players don't let me cause you to give up. But I will likely not be joining.
# I think he does
# since stories are pog
# I'm not doing standard spellcasting
# Yeah we are all dps more or less
# Also that Lawrence guy 👎
# Ranger favored enemy could be handy
# Glad I got that tattoo on sale
# And I could have sworn you said to lvl up before confronting the other party
# And law says randy is in tennesee so he prob couldn't do today either
# Your mace us +1 rn
# We meet online and we schedule times flexibly in <#1090015040389779647>
# Apparently Bood of the Dead has a different version of the trait
# Pretty much
# <@&927426307514581042> tomorrow at 4
# it is your choice if it is good or bad
# That you can't sneak attack with weapons that aren't "finesse" or "agile"
# The slain founders were from Enidor, Oculan, and Thetis
# Opinion alignment is better for (most) monsters. Edicts and Anthema are only really better for players.
# 3 have been given
# Came up this session
# But I'm fine with everyone just mainly working on finalizing characters during it btw
# The hall maybe?
# super early sunday
# I think I understand fully why kindergarten puzzles are used in ttrpgs. Any time we try to do anything harder people start tweaking and disassociating.
# This is up btw
# 6 down
# right now?
# 5. Balentyne’s magister, that creepy Tacitus, has
# been spending a lot of time working on something
# in his tower! I don’t know what it is, but it’s said
# that something unnatural was recovered from the
# north.
# His smite good will also stack so that is cool
# That's what the next mission is
# The what
# Why is the half elf racial traits so scuffed on aonprd?
# yes :)
# My class’s biggest gimmicks are a +2 to hit and attack of opportunity
# I dont think you can shield block spirit damage on the blaster tho
# (As a side note the ranged attack has been fixed I had forgot to fix damage type on a copy paste)
# But they have been plot focused ones so
# my bird at level 4 gets its own actions so later on thatll be fine
# You can find information on rules and the setting in <#868890485899526185>
# Not great service where I am
# I respect the hustle
# Reminder it is your shoulder slot
# No like a rundown of your build +any backstory you have
# I thought we did after killing the gnome
# Does the weekend after Thanksgiving work for ya'll
# i was really tempted to just fucking say square or circle
# then i started thinking the word simple and simple machines came to mind
# Which frankly makes way more sense logically but that may be the 1e player in me
# Question
# Is anyone opposed by me possibly scraping general for a text classification project?
# Authors would be anonymized into integers
# Just make it go invisible 5heaf
# We could use a good spy
# this is most unfortunate
# Did Randall get learned
# <@531348109347782656>  too
# Negating crits is pretty powerful
# Oh wait
# However I would still argue cleric fits better as Gandalf isnt really a full caster
# He typically engaged in melee in a way typical fantasy clerics are portrayed
# That is actually why I added the bludgeoning and piercing attacks
# Food is taking a while
# Fedora = true neutral evil
# pathmuncher is now working and hybrid should be fine. The hybrid session for sunfire didn't have any issues related to it being hybrid.
# Is grumblejack lawful?
# Seems like Jacob is planning for Saturday so Sunday works better
# As a heads up <@&927426307514581042> I'll schedule my stuff dependent on the time Tristin finalizes stuff here (though I may have to cancel cause I'm busy as fuck we'll see)
# As ninjas
# @stfu i dont have the server muted
# Since a lot of npc creatures come from APs or other material I imagine they'd end up having ideals tied to that setting
# i want to do history
# https://aonprd.com/Rules.aspx?Name=Downtime&Category=Gamemastering a lot of interesting stuff
# Things Oracle would like
# +1 heavy steel shield
# that +1 flaming longsword
# Is the reroll before or after the effect is known
# @everyone so basically I'm probably not gonna run it (anytime soon anyways) but can each of you DM me what you think would be a fun AP idea.
# Fallout VATS mechanic
# almost there
# he wasnt even the one who muted you lmfao
# Literal stereotyping moment smh my head
# I see
# he's definitely not a bard
# Like make x npc like you and you can lich on em
# Everything is moved up an hour
# mhw iceborne master edition steam key
# <@!151500793990742016> <@!146626274066956288> <@!492768651389435909>  Y'all want in??
# yeee :)
# at least you know that
# : )
# I mean the only unreasonable chromatic is white
# You ignore social encounter and actively seek out combat. idk what else to say
# Im bery interested in what your plan is
# My brain saw general and was like good enough
# rule is you can ignore the 2 feat restriction on one archetype at a time
# Am good
# Oh I did? Nice
# uh 7/10
# But thanks that narrows down what I should do
# I sat down to start prepping Zeds and was like fuck what if they go to x
# And I can knock people over if I want
# <@&828644223095275611> I got family stuff I gotta go to and Randall feels sick so we are going to cancel for today
# We will see how much i get offered by the walmart
# Not to be racist or anything, but goblin people. *unholy snorting noise*
# <@318536129727168512> ||Your death mommy is safe||
# Depends on day
# forgot that existed
# they sound amazing
# Send character sheet screenshots then. Why do they need you at 4?
# Could we do gnome on a weekend
# All of those work for me
# guys the slavery god isn't bad
# Nvm I canceled it
# I have never used dndbeyond
# <@151489352164311040> <@235883733985525760>
# DEEP SEA DIVER IS A BACKGROUND?
# <@&828644080443326494> I guess tomorrow early time maybe possibly
# Echos of the North (Part 1 of 2):
# Legends and whispers among the travelers of Golarion's Crown speak of a lost tomb hidden in the deepest reaches of the frozen High Ice. The tomb, supposedly belonging to the ancient Sarkorian Warlord Borgbreill would likely contain riches and treasure worthy of the god-king's mythical status. In light of the recent closing of the Worldwound, travel in the region has seen a recent surge and the rumors of this frigid tomb have become increasingly popular throughout settlements near Sarkoris. It's only a matter of time before someone heads North and stumbles upon the tomb and the riches held within.
#
# Luckily for you, the Erutaki village of Nutaqq that borders the High Ice is rumored to be organizing parties for people hoping to find the tomb and strike it rich. Perhaps the echos of this lost tomb could contain your chance at glory.
# I like that at lvl 11 TJ's aura of evil becomes overwhelming
# Reminds me of the collectors edition nameplate
# Also 7 uses of 3d6 channel and 7 uses of 3d6 lay on hands. Both heal him 6 more
# Ok so your ally is lying to someone, you don't know they are lying, you sense motive, nat 1, you then correct them
# The most difficult classes I've taken are  math
# We get a 2nd +1 huh
# What flavor bard are they
# We didn't, but I thought we at the very least got a type on it
# I choose Yay
# yeah I think I'm free at 11
# Didn't see second part
# I go home next weekend
# Azata dragon go crazy
# In that case hear me out
# I might jus grab devon parry idk
# He do be kinda stinky
# and the secret doors would show up on a screen shot
# Damn I start talking bout my house and tristin be like ^
# sumn like this minus the cape
# all but 1 ingredient obtained
# so basically you can do all the main stuff once you get three feats
# So what time we doing this?
# Gotcha
# Guess we'll just see how it goes
# <@318536129727168512> <@589289513788899348>
# That is true
# Looking at playing Thaumaturge
# I was just saying it supports the idea undead pcs should be treated as non-living
# NCSU moment 😔
# ye :)
# what level are we again
# Sunday is optimal
# Should work for me
# Hey all those guys had bucklers btw
# *I'm available most days*
# Oh. Yea I'd have to make a new dude
# @everyone you down to try for tomorrow? I've got the itch.
# <@&868889886839689217> next weekend (28th/29th) I'll try and be in call from 6-10 to assist connecting to foundry and character creation/background
# Or maybe thats anesthetics
# It doesn't have lungs
# since with that you pick between Intimidation or Diplomacy
# I apologize
# Noah being the general
# Fighter, Thaumaturge, Keneticist, Barbarian
# My guess is the other divine dragon is gonna be an archon type thing
# It'll still be named Jelly
# Ah its being listed as from a feat instead of a class feature
# The slight curve he does at the bottom of the second line on that square bothers me
# I think autocorrect got me. But idk how it became hand
# My demon frog made sparky sparky stone
# That's a threat
# Damn no protective penumbra in 2e
# Okay but what if the creature is suffering from warmth?
# They cannot be reasoned with
# a lot of reading
# His brain is in good shape
# Okay so William say Wednesday, Sat, or Sun works for him on this
# not sure how thats gonna work out lol
# <@318536129727168512>  so youre unable?
# and wednesday ill be gone during school hours for a pack leader team building thing at lake logan with 9th graders
# some of the other traditions may be in opposition within themselves
# Btw Cha to fort save <@151489352164311040>
# I guess I’ll just have you spam telekinetic projectile until you get there
# I remember them saying their next thing was going to be non-DnD
# We need to discern a place to do in person
# neither of you are really correct here ngl
# Its sylph only
# Wait its at 4:48 so it will be good
# and being tiny would offset the need for precise shot until you can get it
# No a monks ass only crits 5% of the time
# I might do it early and then just pop in for attendence
# and it still hurts
# one attack for 2 actions
# You sunk my battleship
# that could be stopped by any of their weaknesses
# All have 1
# DO NOT WAKE TRISTIN FROM HIS NAP I AM AWARE HE WILL BE LATE
# i spot a lonely kinsect
# Fair enough
# Most of the stuff my friend does at this point is graduate level I suppose
# https://ifunny.co/gif/onkgGQ1Z8?s=cl_og1c pathfinder weapon idea
# There are multiple spellings
# i was thinking
# oh if i get attacked in a suprise round thats a free +1 ac
# i mostly do it to use any emoji anywhere <a:PenguinDance:779731073004339220>
# but the other stuff is cool <:shrug:858187229779460116>
# Yea they're stored there so it'd make sense
# Elves can begin as either fighters or magic-users and may freely switch class between campaigns (they may also be thieves). They gain benefits from both classes and may use both weaponry and spells. They may use magic armor and still act as magic-users. However, they may not progress beyond 4th level fighter or 8th level magic-user.
# randall wit da history and civilization
# finna be a history teacher
# I honestly couldn't give you a reason he can't see it
# For the one with exemplar
# I vote <@492768651389435909>  out
# My turn takes 8 of those lol
# they are simply living their best life
# but basically
# Assuming i don't get a call from Walmart saying otherwise, yes
# like we were gonna do
# yeah i did
# even better
# I'll disguise myself as child
# ive gotten good on kbm
# Hmm. A message was deleted
# Idk what caverns you talking bout
# THAT'S WHAT I SAID
# I'm good every day but I have class till 5 Wednesday
# increase those times by 1
# Fine whenever probably
# fuck not sunday
# <@&828644223095275611> it time
# <@&927426307514581042> sunday?
# you and fable can see most of it other than the abyss
# Looks good for me, you, and Connor
# I've got a plot line going and it is looking very good
# i see was correct
# look in the guild
# He didn't have shit
# Standable I couldn't make it either
# Pc just turned off on accident. BRB soon
# This would also make sense for things like stores and how they can be more cost effective
# https://www.aonprd.com/MagicWondrousDisplay.aspx?FinalName=Ioun%20Stone%20Pink%20and%20Green%20Sphere <@151489352164311040> if you do not have a competence bonus to intimidate
# Can he show it off for just a second for intimidation factor
# Like it does 2 things
# Also its !gym
# The Dusty Rose Prism one is interesting
# Any plans for when the rescheduled session is? or are we waiting till after sans for it?
# As a note I migrated it a couple version so shit may be bugged
# Try to burn through those reactions
# If you guys test the bow and armor out for a bit you'll realize its +1
# 5152
# 5152
# 5152

# %%
# Add the new features to a matrix
import numpy as np

X_train_features = np.column_stack((numWordsTrain, numCharTrain, avgCharTrain))
display(X_train_features.shape)
X_test_features = np.column_stack((numWordsTest, numCharTest, avgCharTest))
display(X_test_features.shape)
# Out:
# (5152, 3)
# (1289, 3)

# %%
# Fit a KNN model to the data
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for i in range(1, 51):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train_features, Y_train)

    # Predict the usernames of the test set
    Y_pred = knn.predict(X_test_features)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(Y_test, Y_pred)
    print(accuracy)
# Out:
# 0.15981380915438323
# 0.13886733902249807
# 0.13188518231186966
# 0.16602017067494182
# 0.18386346004654772
# 0.19937936384794414
# 0.1947245927075252
# 0.20015515903801395
# 0.20791311093871218
# 0.22032583397982933
# 0.22498060512024826
# 0.2342901474010861
# 0.24127230411171452
# 0.2482544608223429
# 0.24592707525213345
# 0.2482544608223429
# 0.26532195500387895
# 0.2629945694336695
# 0.26144297905352987
# 0.2637703646237393
# 0.26764934057408846
# 0.2707525213343677
# 0.27152831652443754
# 0.2692009309542281
# 0.2660977501939488
# 0.25989138867339023
# 0.2637703646237393
# 0.252133436772692
# 0.25678820791311097
# 0.24592707525213345
# 0.25368502715283164
# 0.2575640031031808
# 0.25446082234290146
# 0.2552366175329713
# 0.2660977501939488
# 0.25989138867339023
# 0.26532195500387895
# 0.2629945694336695
# 0.2591155934833204
# 0.26144297905352987
# 0.26532195500387895
# 0.26687354538401864
# 0.26687354538401864
# 0.2684251357641583
# 0.26687354538401864
# 0.26764934057408846
# 0.26687354538401864
# 0.2660977501939488
# 0.2660977501939488
# 0.2699767261442979

# %%
# See how the model predicts the usernames of a small set of test messages
# This first message is from author2, the model should get this right since this comes from the training set
print("Train")
message = "shops will be included"
words = message.count(" ") + 1
char = len(message)
avgChar = char / words
X_test_message = np.array([[words, char, avgChar]])
print(knn.predict(X_test_message))
# This message is from author13, the model should get this right since this comes from the training set
message = "I'll make one tonight. I have yet to sit down and make my anathema and such yet, so it'll all work out and be done tonight. I'll dm a link to ya"
words = message.count(" ") + 1
char = len(message)
avgChar = char / words
X_test_message = np.array([[words, char, avgChar]])
print(knn.predict(X_test_message))
# These next 10 messages are not in the training set, so the model will have to predict the author
# The authors of these messages are respectively authors 4, 2, 14, 4, 13, 2, 10, 4, 10, 13
messages = ["Also if you haven't played with me before you guys need to do some minor set up on your end",
 "Can’t have double ability to a stat",
 "Because that feels fair",
 "AC penalty instead of attack",
 "Im tempted to play an anadi but it'd be wierd af",
 "So in theory the players are genocidal maniacs",
 "randall taking a nap",
 "Like he has one Ya'll just don't know it",
 "character named Four T'nait",
 "Fantasy continent that tristan made. Sorta generic fantasy, towns and counties that specialize in certain themes."
]
print("Test")

for msg in messages:
    words = msg.count(" ") + 1
    char = len(msg)
    avgChar = char / words
    X_test_message = np.array([[words, char, avgChar]])
    print(knn.predict(X_test_message))
# Out:
# Train
# ['author4']
# ['author13']
# Test
# ['author2']
# ['author4']
# ['author2']
# ['author2']
# ['author4']
# ['author4']
# ['author4']
# ['author4']
# ['author4']
# ['author4']

# %%
# See if the training and testing sets are balanced

display(Y_test.value_counts())

# Create a new dataset by removing all of the authors with less than 20 posts

dfTrimmed = df.groupby('username').filter(lambda x: len(x) >= 20)
display(dfTrimmed)
# Out:
# username
# author4     383
# author2     252
# author6     135
# author5     103
# author7      92
# author14     74
# author13     73
# author16     54
# author10     43
# author1      30
# author15     11
# author11     11
# author8       5
# author25      3
# author12      3
# author17      3
# author18      2
# author9       2
# author30      2
# author24      2
# author29      1
# author23      1
# author27      1
# author21      1
# author3       1
# author19      1
# Name: count, dtype: int64
#      username                                            content
# 0     author1  or did my acid patch thing kill him off my tur...
# 1     author1           pretty sure it was will but double check
# 2     author2                                       I think will
# 3     author2                         Whoever went before Oliver
# 5     author2      Cause they attacked him after he already died
# ...       ...                                                ...
# 6436  author5  Okay so basically I just found out that this A...
# 6437  author6                                            i think
# 6438  author4                       Is the 16 before racial mods
# 6439  author4                                  Aight sounds good
# 6440  author5        20 point buy can't put a base stat above 16
#
# [6291 rows x 2 columns]

# %%
# Split up the data into training and testing sets

X = dfTrimmed['content']
display(X)
Y = dfTrimmed['username']
display(Y)

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# Out:
# 0       or did my acid patch thing kill him off my tur...
# 1                pretty sure it was will but double check
# 2                                            I think will
# 3                              Whoever went before Oliver
# 5           Cause they attacked him after he already died
#                               ...
# 6436    Okay so basically I just found out that this A...
# 6437                                              i think
# 6438                         Is the 16 before racial mods
# 6439                                    Aight sounds good
# 6440          20 point buy can't put a base stat above 16
# Name: content, Length: 6291, dtype: object
# 0       author1
# 1       author1
# 2       author2
# 3       author2
# 5       author2
#          ...
# 6436    author5
# 6437    author6
# 6438    author4
# 6439    author4
# 6440    author5
# Name: username, Length: 6291, dtype: object

# %%
# Check the value counts to make sure the data is balanced

display(Y_test.value_counts())

# Drop from x and y test until every author has the same number of posts as the author with the least posts

minPosts = Y_test.value_counts().min()
display(minPosts)

Y_test = Y_test.groupby(Y_test).head(minPosts)
display(Y_test.value_counts())

X_test = X_test[Y_test.index]
display(len(Y_test))
display(len(X_test))
# Out:
# username
# author4     373
# author2     273
# author6     154
# author5      98
# author7      82
# author13     58
# author16     56
# author14     56
# author10     53
# author1      25
# author11     15
# author15     10
# author12      6
# Name: count, dtype: int64
# 6
# username
# author1     6
# author16    6
# author6     6
# author5     6
# author4     6
# author2     6
# author13    6
# author7     6
# author10    6
# author11    6
# author14    6
# author12    6
# author15    6
# Name: count, dtype: int64
# 78
# 78

# %%
#Extract alternative features from the data

#Vector of num words
numWordsTrain = []
numWordsTest = []
#Vector of num chars
numCharTrain = []
numCharTest = []
#Vector of avg char/word
avgCharTrain = []
avgCharTest = []

for msg in X_train:
    print(msg)
    #NumWords
    words = msg.count(" ") + 1
    numWordsTrain.append(words)
    #NumChars
    char = len(msg)
    numCharTrain.append(char)
    #AvgChar
    avgCharTrain.append(char / words)
# Display the length of the vectors
print(len(numWordsTrain))
print(len(numCharTrain))
print(len(avgCharTrain))

for msg in X_test:
    #NumWords
    words = msg.count(" ") + 1
    numWordsTest.append(words)
    #NumChars
    char = len(msg)
    numCharTest.append(char)
    #AvgChar
    avgCharTest.append(char / words)
# Out:
# pizza hut stuffed crust 🤤
# Oh fair I guess that could be it
# i want more seasons
# ~~Figure out how to get that monk ability to kill yourself~~
# Banish them
# can do! ill rush up and finish the character
# I actually have a coworker named tristan
# but basically
# oozemorph shifter?
# I vote <@492768651389435909>  out
# Apparently he played through the Choral stuff as well
# We're allowed to take two archetypes at level 2, right?
# Presumably to replace the one they are killing off
# God I wish this was legal
# Normal Van Karthy things
# yeah so is resurrection
# <@&828644080443326494> I guess tomorrow early time maybe possibly
# sounds good
# All 4 of them are cracking me up
# Will get on that lmfao
# i am good whenever
# For the one with exemplar
# There may be some pve type stuff but mainly pvp
# Which I dont think any useful info would be gleaned from the human trait
# Probably good for 5
# I am not opposed to them doing stupid shit
# an update about the remaster
# More like dire tiger
# oooooh ooooOO
# I apologize
# That's why I'm wondering Gozreh
# Gimmie a sec working on something large due at midnight
# had to "nerf" her
# We should be able to order those as well from most pizza places
# What is that
# But in all seriousness there is a spell level cap
# checks out
# what if we all crit succeed all the saves
# Multiple Attack Penalty
# Not relevant to you
# O god
# Yeah that's my point lmfao
# I kinda want my 2nd character to be an animist
# I like to think that its body temperature is dangerously high
# 8.5 hours
# A what
# I was gonna leave it open all of Monday
# Use soul gems to craft magic items sounds better
# You don't necessarily need to want to play in whatever it turns into. Just collecting info.
# As a 2nd level power attack fighter
# Nah thats kinda mid
# makes sense
# "hey your the evil guy" " actually no"
# Damn, yeah that's harder stuff than I'm doing
# If you can't find anything, you could code it as two seperate options
# Not till sometime sunday
# You don't necessarily need to want to play in whatever it turns into. Just collecting info.
# same
# jump meteor dodge is always so satisfying to pull off
# True but wouldn't he lose some feats?
# <@151500793990742016> what if w101 again
# dread vanguard antipaladin is literally the definition of grumble jack
# You snag proficeny?
# gnome only spell
# one of us can give the run down post session
# he walks around eating all the mess
# Anyway
# We still have another session until Libarby yeah?
# Those ones are the healing 1hp per minute
# No in 2e :(
# Not in Waynesville that entire week
# dont exist
# Barstools n shit
# fair and valid
# Was it a familiar thing?
# Either would work this weekend but after that I'm gonna be working at Sams until 3:30
# Not glock, gock
# right now
# man he is so squat
# <@458413180893397022> are we gnoming tonight?
# I mean we normally do it Thursday and Friday
# So what time we doing this?
# okay uhh
# Can also just keep grumble jack in the cart as much as possible
# a Man? more like CEO of not being 18
# Btw <@151489352164311040> I drastically underestimated the number of orphans. It is a big orphanage.
# so how does wild magic work?
# Actually may be a couple minutes late
# Will need to stop by the dining hall after my laundry finishes
# I forget if you were 2 for the shrine delivery
# : (
# Like mf why can I not sneak attack with a bat
# Didnt need to copy but thanks
# I think the travel should have been minorly railroaded
# Like removed the option of "anything you want to do" at each checkpoint (Though I was glad to see Fennek on the up)
# wdym i havent had
# <@&927426307514581042> ➗
# Then getting it corrupted
# bizarre that automata aren't immune to bleed
# Wouldnt want to deny them that
# Because they don’t need master in weapon attacks to be useful
# 1-4 Sunday
# Seems like Jacob is planning for Saturday so Sunday works better
# Which one
# (Is it Ironspire)
# I did a short calculation and I'm way less worried about his hp round 1
# This, a picture can tell a thousand words, and 1 picture is a lot easier to look at than 1000 words
# i have shit going on that makes me unable to do the days you want lol
# that mouth does not seem very articulate
# Hey @everyone ya'll know who this may be on my ZeroTier
# Btw <@492768651389435909> what spell you take with eccentric caster
# Is it pure pvp or
# Guess again Im Noah headass
# I'm upgrading Jelly into a giant hermit crab
# <@557292945754030094> you are one awesome bastard
# yall play with a controller or on keyboard?
# So if I say hey lets do pathfinder thursday a week ahead of time I;m gonna prioritize it over something that came up that day
# found something
# Infected tooth
# After next session Justin can go to the caverns
# That's so fair
# This assignment was gonna be for beginners (so basic classes)
# Though is people want guides for classes I'd be happy to make them
# Might be a little late
# yeah but players don't typically heal npc undead. I guess it could be useful in the case of undead companions but outside of that idk.
# Such as today. I didn't have any problem with skipping cause you guys wanted to go get food.
# Hey ya'll I'm going to have to miss this weekend to deal with family matters in the aftermath of my father's death. I'm currently in Stoneville, NC at my grandparents with little to no service. I'm fine with everyone in this chat knowing why I'm busy this weekend but please keep it to yourselves.
# Otherwise I'mj ust gonna go take a nap and be annoyed since this session was all exposition
# True <@589289513788899348>
# Maybe 11 but idk about that
# I think
# Echos of the North (Part 2 of 2): The Fractured Spire
# Three years have passed since the inhabitants of the World’s Crown raced to find an ancient Sarkorian tomb. Now that the dust has settled, treasures have been pillaged, and travelers have returned home, silence has washed over the frigid tundra. After three years of peace, these chilling wastes have again proven to hold much more than initially appears.
#
# After months of unprecedented tremors shook the mountains of Golarion’s pole, the tallest tower of the Nameless Spires began to emit a strange field of magic. As quickly as the activity stirred the abominations that once called the Spires their home to flee, they shortly returned both greater in number and with strength unheard of for mortal creatures. The tower soon launched crackling energy into the clouds tearing the very sky asunder. As the cracks in the sky grew, it became evident that whoever armed the ancient tower plans to tear a rift into another plane. A catastrophe that could prove more lethal than the Worldwound. As the earth begins to tremble once again, it is clear that something must be done before Golarion itself is torn apart.
#
# The Wandering Skum is again organizing parties, hoping the few remaining heroes are strong enough to save this land from the ancient powers that echo through the ice and snow. While locals fear the tower has been charging for millennia and that this was their true purpose, those who saw the mythical might of the warlord that lurked within that Sarkorian tomb can sense his power in the Spires.
# As ninjas
# i can
# If I ran Starfinder it would def be in the base setting
# I'm not a huge sci-fi guy but I may run one-shot stuff here and there
# https://www.aonprd.com/MagicWondrousDisplay.aspx?FinalName=Ioun%20Stone%20Pink%20and%20Green%20Sphere <@151489352164311040> if you do not have a competence bonus to intimidate
# I can give you a blank one if you want
# Tomorrow at 5 <@&927426307514581042> ?
# does it prevent you from casting it on yourself
# It genuinely stresses me out and makes me not mad but upset when you guys don't show up
# <@613394585330253844> avinash with the buffs got some crazy damage
# how is it looking <@!458413180893397022> <@!151500793990742016>
# Basically ima drop 3 sessions worth of summaries, get 60 exp, then use 4 days of downtime to get level up. Can the rest of my downtime be me spending 80gp to get lvl 5 house with a ritual room?
# Okay what is a regular time that works for ya'lls schedules <@&1064607664216231997>
# Rn I'm considering maybe something like 1st Sundays of the month
# Which is a really weird gap in the rules
# Are you referring to the announcement?
# i just tend to never make second characters
# However I will be spending this weekend migrating Gnome to Foundry
# Check <#959986961815322724> for more details
# Because if I confirm I won't be able to
# What all loose ends can you guys think of?
# So they should have 2 left if I am correct
# did you just @ or is my discord hallucinating
# Did they ever make archetypes for exemplar and animist?
# that exists
# its actually <@&828644223095275611>
# if not remedied you will be defaulted to our economy plan: "Someone really strong wants you dead and may or may not take action the moment you hit level 3"
# I think it is a threat
# i guess one of mine is too
# Make randall the guard that krilin was fucking with
# ive always heard charisma casting as being enforcing your will upon the world
# I work
# I'll there in a sec
# My brain saw general and was like good enough
# like elf and hobbit can be 4th level fighters and dwarf can be 6th level while a human can be 11th level
# and yeah unarmed strikes not being covered would be really strange
# I still don't get why you posted this
# ||im joking ^_^||
# Aight its Gnomin' time
# ~~Unless people want me to push it back some~~
# Lich newt does 1d2-4
# No writing allowed
# Here btw
# God now I have to make a monk with that
# For general knowledge, I bought a pearly white spindle aeon stone
# 4 having been at hec
# Was asking for code reasons
# and dont forget your class on figuring out it you want comp sci or comp eng
# add that to the end of tris
# Sunday @5 <@&927426307514581042>
# So Ephraim has dropped
# Start there then go down
# <@318536129727168512> Is it fine if I change to a Fighter, because I haven’t played yet?
# Wait so ifrits
# hear me out a halfling witch with a permanent reduce size and it has  a familiar with a permanent increase size so they can ride their familiar
# Scream it from the roof of the library
# they are, because dhampirs aren't undead
# Sounds good
# Fridays at 5?
# i leave at like 7
# I'd have to wait and see how it looks in monster core
# Do you have the spell that lets you sleep in armor?
# So that guy in kingmaker
# I'm not gonna be ready for real college moment
# character has been made
# I’m good
# The oracle should take that scroll I think
# So since we are doing a single cohort for the whole party it is going to work a little different if multiple people take leadership. (Also followers are additive)
# 1 person has leadership: Cohort acts normal
# 2 people: The Cohort is only one level lower
# 3 people: The Cohort gets +2 skill ranks per level
# 4 people: The Cohort gains a bonus feat that one of the people with leadership has
# 5 people: The Cohort gets a +2 to a stat
# they all give basic undead benefits same as skele
# I will say be aware that stuff is already in the works for it to appear in my west march
# was wastelander
# like Striga's day armor in Castlevania s4
# they sound amazing
# But they provoke even when stepping into a square
# Which ones the better one, I'm only reading it for the first time now
# <@&927426307514581042> I forgot to message yesterday
# But <@589289513788899348>  seems too busy to do Gnome + this rn
# And idk if <@378709482953244672> and <@151489352164311040> have characters made
# Or fridat
# I have to make it first
# All good just dm what kinda build youre thinking (melee v ranged, martial v caster etc)
# an extended minute
# A group of roughly 5-7 random wierdos.
# Makes sense
# <@&828644080443326494> which one tomorrow
# With grazed only affecting skill checks
# <@589289513788899348> <@287398314796908545> don't forget to put your characters in <#868890602186608670>
# My address is 1082 Jonathan Creek Rd. just ping me with a time whenever you figure out your routing
# got it
# <@&828644080443326494> gonna have to cancel tonight. I have to leave for family stuff.
# ~~I mean ya'll are getting ass blasted so~~
# We got spooky dragon vermin pursuit
# postkinghts on mobile was pretty fun
# I mean its fine
# I just didnt realize we were on
# (I have procrastinated map making)
# Instead of smite good you get smite nature
# Technically i could either sleep asap after calc or mid day
# Why the fuck didn't you send the days then as well
# thats crazy tj
# Van Karthy aquatic adventure when
# Yall good for tues
# Can it have a charisma buff at all
# to make it more understandable
# 1. Lord Welshire has taken the army and gone to join
# the war. What if monsters from the Caer Bryr attack?
# We’re defenseless!
# That was partially luck and partially comp
# <@492768651389435909> wby?
# I think edicts and anathema won't be that extensive unless it is a more complex creature as well
# Or maybe Norgorbur's identity before he ascended is discovered
# I'll put that in the treasury
# almost there
# <@146626274066956288>  :game_die:
# **Result**: 1d20 (17) + 11
# **Total**: 28
# Oh shit I have Alchemical Crafting apparently
# Instant death
# I don't want to enter the dorms when I don't even live there
# tommorow i would have to leave at 8
# Fallout VATS mechanic
# Which 2?
# ddraft or alchemist
# Dusty rose cracked prism is cheap as hell
# i feel like being an undead skeleton man isn't exactly being a living creature
# and unlike automata being called out as being living creatures despite being constructs, skeleton does no such thing
# The dual balanced weapon mod is interesting
# Tap inner beauty
# <@&828644080443326494> so shit sucks plans got canceled so want to try and finesse balentyne.
# Technically I cheated cuz I put multiple games in one box, but they were of the same genre/series so
# stop texting start driving
# If 2e allows me. I shall do the same
# i dont get why they didnt just use unholy
# wanna help me with legiana
# Oh. Wierd. I'll have to look because I have no idea this was even happening.
# Gonna revert back to frog
# <@&828644080443326494> 10 min
# If cool with either
# <@151489352164311040>  :game_die:
# **Result**: 15d20 (2, 10, **1**, 13, 5, 7, 13, 5, 5, 15, 5, 9, 3, **1**, 13)
# **Total**: 107
# just get some Gar
# but story
# I go home next weekend
# NPC can clean up a little and be fine
# leaving waynesville?
# Likely can tomorrow
# different dimensions
# imo running off to find shops and sketchy theives is fun but it takes a while to do every time
# 4 work
# Also updated and put foundry up please make sure your sheets are working <@&927426307514581042>
# why am i pre muted
# Leshy
# Dante
# Very rough encounter got even worse after Fable fell off a cliff
# We are fucked
# Work at 2 Sunday so it would have to be earlier than oli awake early
# It be 5
# Apparently I am not enough of a gamer™️
# But at the same time how much i pay attention in total leaves a little to be desired
# Walkibg back now
# Yeah thats how I've always used ruler
# Didn't know about the right click pop out
# Player ones at least
# I may consider human cause it might just be straight better
# Mfw you could say “hey can’t do Tuesdays”
# Btw commoners dont have a favored class Im pretty sure
# ive just never touched the safi
# Write message in alphabetical code
# Subtract the values of a looping code word
# Sounds good to me
# I killed 71 Googlies and 24 Booglies
# i think
# It isn't that he's literally "living" he's just treated as one for effects cause he lacks immunities or something dumb like that
# Gnome @5 on Sunday work <@&927426307514581042>
# So is this a all level 1 mission
# We lova casting spells
# He didn’t get spells this level
# Over 1.5k hours
# This ended up becoming 3 scales
# Nat 1ing anything else just means it doesn't like you for 24hrs
# More holdscarred for that matter
# Hey does the chupacabra keep the grab quality on it's bite?
# aka probably
# He hasn’t done anything. Yet.
# we ended
# Also I need to ask Tristin if I can use moly on the check
# Is this small enough
# Champion can get all the paladin abilities though
# THATS NOT YOUR PFP
# When gome?
# My normal plan is to walk up and Power Attack it to death, but I have a suspicion that it won't work here
# the summon level increases every 2 levels
# you dont want to know
# same for wizard 101
# +the game is pretty popular so
# you know tin in valheim
# Didn't want to put questions and stuff in hall
# Ided by Ollie
# Hi good Im Noah
# Make a channel for this
# Well then the turtle shall starve
# Si, I am editing a Floorplan
# Your character has basically sat in the corner for several weeks
# adopted ancestry also specifies common
# Uhh I might not be but you can go ahead without me if I can’t
# I was tempted to pick barbarian
# But going ranger lets me attack a bunch with effectively no penalty
# for most dex classes it would be better than power attack
# I wunna play that when it comes out
# doesn't get better with two handing though
# My head cannon is that when a barbarian goes down while raging all of their wounds basically grow
# So just Randall and Noah
# he's a bit quirky
# AT Nergigante was honestly peak World
# https://www.aonprd.com/MagicWeaponsDisplay.aspx?ItemName=Prying%20Star
# this sounds cool
# K so Ephraim is officially droping
# what im reading is the "original rules"
# Not in wotw
# Big W for big Magic
# Should be fine
# das not a room
# <@458413180893397022>  :game_die:
# **Result**: 1d20 (3) + 9
# **Total**: 12
# and I can see them when looking here
# Btw if you want with the wrestling thing two people could make level 6 characters that work together
# Mario strikers
# Spicy food
# Rowing
# Gang fighting
# Rum
# Silly street names
# Asmodeus main festival (Halloween)
# Burgundy
# Mints money
# Duke is unmarried
# Tiberius Thane magic school
# Fair but that feels like a different kind of limitation that rules lawyers will take to seriously
# K so you haven’t leveled up recently
# Its 4/1
# I was subjected to change
# Try being jobless /s
# I can do it simpler than that
# all the level 18 kineticist feat names are absolute bangers
# It also was present in the original DnD
# I still need to do a lot of the other stuff related to this map as well
# :) wolves
# foundry is up btw
# Ie all the recent jokes about immortal snail assassins
# To make sure this gets underway I will be doing the first session sometime in the first week of November
# <@318536129727168512> i sent you one earlier
# Not I
# Doing the kingdom stuff
# TJ decided
# Weird
# Fix it or no?
# You ever tryna piss outside and a fly lands on your dick?
# Fortunately I can't relate
# Also my phone keeps trying to autocorrect anadi to Canadian
# I vote we murder hobo, that would have been so much quicker if we just killed the king first thing
# Yea I need to learn type 1 and give it to awakened animals anyone plays lol
# lance gang
# Check out west march channel at very top
# Gorgar on his way to Oculan
# <@&828644080443326494> whats the % chance of tomorrow?
# I'll speedrun build my character tonight then
# why couldn't we just go knock on the door again
# thats a lot of bows
# it was announced
# But from what I've gathered Book of the Dead needs a remaster
# Animist seems like medium which is my favorite 1e class
# that just kinda skips most of the defenses
# Man I just had a 20min discussion with my English teacher about Kingmaker
# am i considered a living creature for spells or nah then
# Was explaining for them
# Should work then I think
# Time to remake a map in dungeon draft 🙃
# its wierd
# It makes sense, the teleportation is space technology
# Scroll of Exchange Image, Forge, Harm, Celestial Accord, Flashy Disappearance, Overselling Flourish, Detect Poison, Feather Fall
# 1 Numbing Tonic, Warblood Mutagen, 1 Silver tongure mutagen, and war blood mutagen
# 2 Healing potions (minor)
# 1 Oil of unlife (minor)
# A manuscript
# 2 Potency Crystals
# but without the benefits of being able to turn into a werewolf
# My brain didn't even consider Roman numerals
# It would be good to know for ocean navigation anyways
# And it shall be wotw
# sunday still works
# here me out. Make all the monster hunter monsters in pf. And you can just make their level equal to the HR needed to fight them + 2
# Some but it would def take some work to cross over
# If I had a nickel for every alchemist I've know named Rana
# fuck not sunday
# That’s the reason I didn’t go to state
# any preference for what channel I make the item thread off of?
# it just feels like a conrasu should be a construct
# I think I'm good
# Yeah I think they will port it as an anniversary edition
# oh wait i am not
# Theres a halfling only feat that is power attack but better
# im confused, wym?
# Work early sat
# I think the plan was
# Go back to kobolds
# Go talk to gripplis
# Go south and get horse for paladin
# Go to other grippli place
# Go see if we can find Oliver mom
# V is a strong orc letter
# uh 7/10
# but the dog is cool
# surprise doctors visit might make me a bit late
# you can do that anytime before first session as level 2
# Wb Mon Fable
# I might get an Elemental Sentinel from Furic
# Can move it either in place of Gnome or King that week if it makes life easier
# Undead Dragon
# Pretty much
# I'm not doing standard spellcasting
# The queen?
# But double check how scrolls work first
# ||Spoilers: They're in your walls||
# But I am cool with it
# I am in a word game with Law but will join when others do assuming we are still on
# Humans only take
# <@&828644080443326494> one hour. Be there or be square.
# yeah they also make having permanent minions make more sense
# Tristin has a module for it in pathbuilder and foundry pinned in 2e resources
# Crystals are just what I had been imagining
# my ~~ass~~ heart into pieces
# ||working on black friday would be, interessting....||
# He got special permission to sub a bunch of undergrad classes to double count credits toward a doctorate
# so according to pfsrd the only cost to become a graveknight is i must spend 25000 improving my armor
# whats your damage
# increase those times by 1
# That's fair
# checks out
# What you gonna do against the gloomblade^2
# For those doing the gremlin hunt, we should all exaggerate our kill numbers at the end and see if we can trick feyhunter
# <@&868889886839689217> reminder this weekend (28th/29th) I'll try and be in call from 6-10 to assist connecting to foundry and character creation/background
# Eh whatever I'll just test it. I'll use both mine, kobold and sunfire.
# i would be so down, it sounds awesome
# Well our group is the Nesscian Knot or something right
# i would say tommorow then
# That is true
# <@458413180893397022> <@151489352164311040> how’s
# there could be a war starting and she
# Totally forgot I had the wayfinder of hidden strength
# I will say that currently the cleric has not been reraced yet
# I SAID NP
# If you guys test the bow and armor out for a bit you'll realize its +1
# Ruff even
# i want kingmaker
# Gnome this Thursday?
# -Blink doggos
# For people who aren't sure on edicts and anathema I suggest looking at this campaigns deities or the deities on archives
# Join main voice cause your ass making no since
# Fire bitch is gone
# and then some monsters may have stuff saying they don't follow those exactly
# <@531348109347782656>  :game_die:
# **Result**: 1d8 (2)
# **Total**: 2
# Oh. Damn. How?
# <@613394585330253844>
# > ## Welcome to The Weastern Marches
# > Now that you have joined you can get information on the campaign in <#868890485899526185>
# > If you have any further questions you can DM me or ask in <#1154848615773253682>
# > ### Making a Character
# > Once you have your bearings the first thing you'll probably want to do is make a character
# > [Archives of Nethys](https://2e.aonprd.com) will be your go to for info on pf2 and [Pathbuilder](https://pathbuilder2e.com) is the easiest character sheet to start
# > Once you have a character you can register it in <#868890602186608670>
# > The last step is to make sure you have foundry set up which you can see how to do [here](https://discord.com/channels/793006067361120256/1154848615773253682/1164242182169968719)
# > ### Getting into a Session
# > Once you have a character you can head over to <#1090015040389779647> to work with other players to schedule a session
# > Once you have a group, time and goal you can follow the template in <#1113467077873913866> to officially schedule it
# so imma join
# Prob not
# Family is still here scheduled for lunch tomorrow
# You've told me that but this is the first time I've seen it in an official capacity
# Just pulled up the page yeah budget version
# Okay I need to move wolves up a bit
# Yeah but it isnt your prehensile one
# Basically, I know that im just pulling dick moves but at the same time, i have the freedom to be busy and/or "busy" elsewhere
# although that depends on what you consider exposed to direct sunlight
# Im unsure on somatic
# Pull the Dalton
# You get diplomacy instead of ride
# Maybe they are gonna release an Ap with some time travel chicanery
# And a snake
# This is gonna take at least another 30
# So if we get the shield or armor then we still need to get proficiency for them right?
# Pc just turned off on accident. BRB soon
# This ^
# Reduce- Kill minions or let them get killed
# Reuse- Make them undead
# Recycle- Use the bones to fertilize your garden
# I school until 700 mon-thurs
# And have a meeting at 700 on Thurs
# Besides that I am free
# I mean King got a 2e remake and Runelords has like 3 different versions so
# No. Maybe a mobile issue
# <@&828644080443326494> oog
# No. I might just get the thieves tools and grab leather
# On the case of the shambler & 1st draugr encouter I think that was just a party spread issue with there being a lvl 1
# Thank ya
# wah steam is buggin rn so I cant see it
# Plus it'll open more potential for goals and such
# I've been made aware of this by many
# You grab a creature with telekinesis and use it to batter nearby opponents or objects.
# If not, I play a Kashrishi and that's still cool as all heck
# sleep time
# Am I good to close foundry
# But I doubt you plan on finessing anything so
# and the accounts are free
# Its a good structure to make one
# like charcter sheet?
# For me remembering shit at least
# wtf is this
# *and social anxiety*
# Piercings dragon
# <@&927426307514581042> Would ya'll be up to start slightly earlier?
# <@298277388800753665> this category is where everything related to the campaign will be
# I've got a plot line going and it is looking very good
# The summoner has been linked to the summon
# Do Mirage and Fortune counteract eachother in that way?
# Yes this will probably be replaced with the wild magic table
# it up
# That’s fine. Looks like each race has a spell 1-6
# I would be fine with earlier time
# Would be pretty funny
# all legit
# Not even good reason just decent reason
# Good, if I had to suffer then so does everyone else
# uHhh sure
# and could make interactions more interesting
# Animism and whatnot is all I know related to that word
# Fair enough
# but from my first look at the ikons
# i would not call them internally balanced
# Kobolds are officially unrelated to dragons by blood
# Uno momento
# I dont think so but unsure
# All of those look interesting
# I have dr's appointment at 5 but it shouldn't last over
# and being tiny would offset the need for precise shot until you can get it
# Neither is Fable
# He can be the dog
# works for me
# For both
# something like that
# Thinking night of 4/6 perhaps
# <@!318536129727168512> <@!318536129727168512> <@!318536129727168512> <@!318536129727168512> <@!318536129727168512>
# or when some kineticist summons a star to the battlefield lol
# <@151489352164311040> 👀
# yeah they small
# If it gets the kingmaker treatment it'd probably go more off the game then the 1e version
# But only 8 levels?
# <@&828644080443326494> Saturday Monday early
# All aboard the Gorgar express we can all go 7 hexes instead of 5 when I'm around
# Or telekinetic fox
# once a ranged weapon always a ranged weapon
# +4 strength
# +6 prof
# +1 potency
# <@&868889886839689217> I'll be in call starting in 13 minutes
# raven that sits on a tree and pretends to be a Funny demon worshiping tree
# Nature or Local trained?
# then they start coming in hordes
# Good question
# Hey can ya'll go through the stuff in gnome hoard and tell me what ya'll took, what ya'll left with Zed, and what ya'll trashed
# im ngl tho that 1 hour break was just nice
# <@!151489352164311040> wanna join a call and I can tell you a bit more info you find in the orphanage
# do you mind if i jump into foundry? is it open
# There are multiple spellings
# 11. Bellam Barhold is such a lush. He does enjoy his
# wine. He’s always complaining about how he can’t
# get any of the good stuff here in the borderlands.
# Hedge Cloak
# Unless you think you can get back within a short time
# will soon
# Damn no protective penumbra in 2e
# I didnt prep it
# and by that i mena noah
# dealing with family
# Although it’s possible I get pulled away by parents
# Should be good!
# I'm free Wednesday and Saturdays
# But just thought I'd mention the weird shit
# Lawrence can't make it so if Noah can we will if not we'll just skip. Probably doing kingmaker. Gonna want everyone for way of the wicked. If we do do it.
# will have to confirm tomorow tho
# mouse on mouse <:wah:951310823366754334>
# The system can def make it easier
# ^ randalls 10
# Vurgas and Sarah
# Same rule. You can make whatever changes you want before the first session you play level 2
# Wait how does shield blocking energy work
# Selfish bastards
# Might just give the worg the infernal archetype to simulate that
# uno mas
# Oh. It's at the top. Oops
# 5 shuriken attacks each turn with 300ft range
# highest MAP is -2
# Opponent becomes off guard after a single attack hits
# I feel like they said they started working just weekends
# But it does have a timeline I think cause Vordekai and Armag
# Owlcat is based (except for that data scraping thing)
# How do i go about deleting the wizard class and reselecting it
# Well yeah but barbarians just
# Bones Oracle
# But yeah kinda how I'm leaning
# Which version
# Or is it still 5
# <@589289513788899348>  <@492768651389435909><@146626274066956288>?
# smh don't reveal company secrets
# an idea has spawned
# I was bouta say I don't have tables but
# Those just expand your pool
# you have not found out
# Current effect of the bear pelt
# I use paid on mobile because the giftcard meant I didn't have to pay for it lol
# prob cant tomorrow or saturday
# This is gnome general
# I am not
# Food is taking a while
# Rituals are hard
# Or Sunday
# acuity is close sounding to agility
# And acu may be confusing if characters have an "ac"
# <@&828644080443326494> reading up on stuff and it would be beneficial if multiple people take leadership. Mainly those with high charisma. It would still be beneficial even with no charisma though.
# I’m good with whatever anyone wants to use
# Fair enough lmao
# <@554770810556907540> am I missing something here?
# <@151489352164311040> you can put you character in whenever you are ready
# High or low as good
# works for me
# I thought we did after killing the gnome
# The oracle can get it next level
# neither of you are really correct here ngl
# I mean the plants are still living and they are somewhat suffused with the plants
# I have 492hrs. Not as many as yall for sure. I've got 100% achievement on steam though, and have done multiple master mode runs. But yea yall are much further in hours.
# More of a just what my week looks like than a regular thing
# TJ gonna need paint cause his ass is blue
# gome <:wah:951310823366754334>
# But can it provide +2 hp for all of old one eys hd?
# Big changes with Wizards (for me at least).
# I get simple weapon proficiency.
# Apparently I can cast with both hands full now.
# School gives me 2 spells and a cantrip (cantrip is weirdly worded, dm may choose if I get it.) (At level 1, this is opposed to normal +1 cantrip I think? And one spell per spell level for the school.)
# Each level up gives you one spell from your college, along with the normal +2 spells.
# I believe I would use the School of the Boundary.
# <@!531348109347782656> <@!318536129727168512> <@!458413180893397022>
# Brilliant Plan:
# Step 1) Both west marches go to space
# Step 2) Colonialism
# Step 3) War
# Step 4) Profit?
# I'll be able to grab it at lvl 12 but that's a little ways off
# Would be helpful for necrocrafts and Artephius
# i have like 7 int
# did u just make like blank characters to cover up the map?
# ~~Please do not invoke the Archon's name~~
# What about beverages
# <@613394585330253844> Avinash has been under leveled for a couple sessions
# As a note I migrated it a couple version so shit may be bugged
# So traps. Gotcha
# If I catch the car on fire we can push it back by 15
# It’s 5:30 already
# in call
# im looking at a familiar archtype that lets you take
#  evolutions
# on a d100 there is an 11 percent chance to roll between 90-100
# Hmm I wonder why that happened lol
# uh oh
# i might be colorblind but at least im not deaf
# As a heads up <@&927426307514581042> I'll schedule my stuff dependent on the time Tristin finalizes stuff here (though I may have to cancel cause I'm busy as fuck we'll see)
# The fall harvest has failed. The village is starving and it has become clear that your small town is unlikely to survive the coming winter. All the while the cruel Duke Autumnhall has continued to maintain his lavish lifestyle in his secluded manor. His servants talk of a magical horn able to summon a near endless amount of food and drink. With all requests for aid being met with harsh rejection, the mayor has called an emergency meeting to discuss the only course of action that remains...
# ___
# Looking for a party of 3 - 5 people
# Aiming for 1 to 2 sessions total
# Character lvl 3
# Starting gold is 1500
# Stats are a rolled array:
# 18, 8 then 1d10 + 7 (roll 5, drop lowest)
# Anything PFS legal, ask otherwise
# Perception is class skill, Precise shot is optional
# **Starvation rules are in effect and foraging will be harder**
# If interested react with a 👍 and DM me a character
# Respond with your class and party role if okayed
# I especially like fated shot and noble branch (prob cause they aren't basically copies of fighter feats)
# I'll use one
# Was this the bad idea <@318536129727168512>
# Could we make a day job check for a lil extra cash?
# this feat sounds dope
# That is a thing that exists in 2e (which I forgot about)
# I was just being more general in tabletop
# So casting will only fuck up on a 1
# if we knock again they would be sus
# Pathfinder on Foundry VTT Community and Volunteer Development Server #paizo-blog
# Plan to run it 1e
# I may need to go through and just universally increase numbers
# yo tristan im gunna update my guy with familiar now
# and could only be cured through high level magic
# also my ac gunna be shit until i get some gold lol, i skipped out to save a little gold ill admit
# This description on hideous laughter cracks me up
# A creature whose type is different from the caster's receives a +4 bonus on its saving throw, because humor doesn't “translate” well.
# If it’s good with his parents I guess
# Cause aren't both immediates?
# Especially if you bust through the wall screaming
# I'd be down
# I'd hard pass on otters they are major assholes
# folders act weird
# Did they replace it?
# zach, is your character little guy, beeg weapon too?
# I can still do 6 potentially but
# I'm building a 10
# Got it
# They're in your skin
# Ah gotcha
# Close range coating
# no i like him, but every single comment under the post says the exact same thing
# I made a second character
# outside of just making it'
# Vorc the Orc Sorc of York
# ok so basically
# I remember them saying their next thing was going to be non-DnD
# And law says randy is in tennesee so he prob couldn't do today either
# <@!151500793990742016> feed us
# Thats fair enough, I generally run my dragons with a tolken bend so they are more lethargic
# Ah this isn't dms lmao
# Hey Tristin is Pathmuncher up to date?
# My stuff is hanging
# I can enter it manually if need be but
# unsure without looking at my character
# So how about the 25th or 29th?
# We can start at 5 btw
# Checks out now that that is changed
# Fighters finess is a little nuts
# I'll take a look
# 30 abilities added to foundry 😔
# That escalated quickly
# And I do mean coffee
# i spot a lonely kinsect
# <@&927426307514581042> Tomorrow be there or be square
# Also Foundry will be up most of today is you guys wish to adjust characters
# Then I'll just have to work them into the game.
# I’m good Tuesday and Wednesday. Thursday and Friday I’ll be working.
# So against level 1 DC that’s like 50% chance of crit success
# Best spell
# I will count my original one as close enough
# Gonna be late <@&927426307514581042> start at 6
# Are there any penalties to swimming / being underwater for wearing heavier armor?
# Level 3 presumably
# Send character sheet screenshots then. Why do they need you at 4?
# And that kills him
# Boncing Persistent Bestow curse makes me feel a certain kind of way
# The basic recap on the few sessions so far
# 1: Arrived in Casus and met some of the starfall wayfarers (the org you are joining)
# 2: Killed zombies and saw the shambler
# 3/4: hunted bandits
# and those can change every time they're channeled
# I'm busy Monday from 4 to whenever Greg is done with whatever he's wanting me to do (7:30 at the latest)
# Instructional Guide for my Technical Writing class
# That and 20k isn’t much at high levels
# We will also be using wound thresholds as well as a homebrew wildmagic system
# Honestly between that and mystery stuff oracles have the same amount if spells as a cleric pretty much
# That's a threat
# Just gonna point out that limitation is like saying you have to be an iffrit to cast fireball
# Tristin do you mind helping me with some stuff rq
# I got stuck on the retraining
# Gonna wait till when archives updates to organize grimy gremlins so people don't get confused
# would a one action system be bad?
# I'm pushing back to 6:30 something came up
# server muted for his crimes against wizards
# Eats the Necronomicon
# i really like fire-earth
# lava leap is cool
# looked in the compendium and saw the new wizard schools
# The risky striker feat has some chad energy
# yes for me
# <@&828644080443326494> tomorrow at 1
# plus rare things generally coming from one place, so I just checked where the most logical place for a Goloma would be
# I don't think we've had draugr
# I am down
# Aight so <@244474569102983168> Scroll shop located
# Its not even a joke
# Its a place
# Same thing though
# Okay so I guess Ill start planing around when I get my schedule
# Plan is that we will do the last part of varnhold on wednesday in kingmaker and on thursday we will do wotw cause it hasn't been played in a bit.
# Leadership + Undead Master
# Unsure on break
# io @everyone
# In the end awakened animals will end up just being a custom ancestry
# Good for me!
# then just sunday
# Yea I figure, I'm just curious
# try not to kill the rooma next time
# <@244474569102983168> we got a session if you want to join
# I think humanoid is supposed to be a biology thing less than a shape thing
# I should get one of these as my backup ranged weapon https://2e.aonprd.com/Weapons.aspx?ID=336
# gun lance gang
# Hey <@&927426307514581042>
# The Foundry server has been migrated successfully
# I will be hosting the server for the bulk of they day please take the time today to join an look over your characters to ensure there has been no regression on your character sheets
# Probably. Might have to be early if I can't get off that day
# Okay so a couple small things
# Where tf does Lawrence live
# Me something with greater invisibility
# Also me insanely charismatic
# it'll work for me 90% sure
# its sooo much
# gets the divine spell list
# and prob tristan
# there ya go
# In a phrase "Murder hobo"
# Van will seek out this information next time he's in a large city
# YOU WONT TELL ME WHY ITS DIFFEREN WTF
# Did the chat clear itself?
# and then similar to pf2 at later levels you will get extra actions for certain things
# I recall now
# not enough bards honestly
# Yeah so that would make a good ally for low lvl cohorts if we get a new organization
# i want to do history
# It's why we're doing a test
# Sorry, got my days off by one
# yeah law you can do whatever
# cool math can go in the 10th square for honorary mentions
# Fair enough
# Most of the stuff my friend does at this point is graduate level I suppose
# 19. I hear a raven arrived at the rookery last night! I
# bet it carried important news though I know not
# about what.
# Also if you haven't played with me before you guys need to do some minor set up on your end
# never felt a high like that in a while
# They have life essence or something I guess?
# or hero forge
# ^fun idea if anyone wants to in the west march
# Yall ever play calamity mod? Shits wild
# of damage
# This the one you are gonna play?
# but I can put those in chat easily
# I meant to saw I am idk why I changed it to I do
# I don't think you finished that first line
# We should go through places on the way
# So we should be good to run both next week and the week after <@&927426307514581042>
# Sorry for my brain damage
# Sounds like a plan
# im good for today but would prefer tomorrow
# but not a loophole
# Ye he is
# What about ya'll?
# Alchemical Bomb for the favored weapon
# I may advertise in guild server but have a limit
# That's such a deal
# What is 3rd class
# That's called a boggard smh
# That had occurred to me
# Brightblade's Bravo:
# 3/day as an immediate action replace a save with Fort + demoralize enemies who witness
#
# <@151489352164311040> Was a sample I had for you
# I think so
# They can prob still look like the left but that is like the savage version
# that seems more anti-hero than anithero
# Could be closer to 5
# Just to make sure Ive preped correctly you guys are planning on finishing the forge this session?
# I've got the server down to 40ish channels so far
# and the points he made in the video made sense
# I would be down for an alchemist crow though. But i feel like he wouldn't be able to carry jackshit without being over carry weight.
# Wilderness so far, but nobody has really looked into stuff happening in the town very much.
# I was trying to send the monocle and had a spasm
# Replace head with snake or become human idk what to say
# They have a replica grill
# I know lmao
# Fu you I'm balls deep in java rn
# i need a 5 paragraph description of each book
# and uh
# I am good
# I thought you meant that feat
# Wait did you disable it entirely?
# ninja sounding kinda fun doh 👀
# I still weep about Armag in Kingmaker
# Can we do this thursday
# The slain founders were from Enidor, Oculan, and Thetis
# Apparently Bood of the Dead has a different version of the trait
# I think that was realism issue
# so their roll was invalid
# This spiked mace
# never lose joepe
# I guess, well, in fuckin buying it
# *the quad ancestry anadi build takes no pre-approval*
# but like anywhere in canton
# I think so
# Still trying to but unlikely
# The 1e prep agony
# Tomorrow is online, right?
# I win
# How long was that bike ride
# You feel fine for 6 days after a ghoul bites you and then just perish
# its a bit funky
# Then I can stack it later
# sumn like this minus the cape
# I have a bus ride to waynesville today
# Most dm's wouldn't give you that freedom
# <@&927426307514581042> Does Sat or Sun at 6 work for ya'll
# may be a good trade
# For anyone
# great jagras down
# That works
# Would need Mitra attunement all the way through
# and also really funny in how ludicrous they are
# Just remembered my parents are visiting tomorrow. Probably only a day trip so should be gone by at most 7.
# Certain rules carried over I thought, but I could be wrong. Sorry then haha
# Nah to both
# Not the biggest fan myself
# In the Player Core, I'd say Bard probably
# sheeeee is SKETCHY
# You can find information on rules and the setting in <#868890485899526185>
# My b I did forget to announce this week
# i put many many hours into that
# Ill just let yall distribute any notable items off him then give you potions with a gp value equal to 4th lvl character wealth - items you loot off him
# And that's kind of on all my characters
# <@151489352164311040> Oliver has joined the party
# id say the only things that matched that difficulty spike were AT Nergigante at the end of World and Fatalis at the end of Iceborne
# made a thread so I can store all the ways karma can take effect
# aura of despair
# Summoner main represent
# Seems Mondays it is
# What time
# Death was fun but not one of my favorites
# I get force tho cause like nothing is immune to force
# Can you do the early time tommorow
# My man Norman Gerber gonna get outed
# Guess it's the same reason you can get that sick giant ancestry
# No I think you'll need the enchant for that
# btw the push your luck rule was a great success
# Cause it 1e it was all demonic and witchcraft except for like 2
# Sounds good
# <@&828644080443326494> 1 hour
# His Aura
# Randall pulling a me
# Name:Fenla
# Class: Kineticist (Kinetic Chirurgeon)
# Role: Ranged/Healer
# Now I don't know how to respond
# I call exploring danger
# Copy of foundry link
# Can you not hear us?
# Okay so for Tristan westmarch I will have bone wizard the utility dude
# That is another complaint Id have
# Cause sure I know how a spider or centipede behaves
# But how exactly am I do determine how a black pudding or another creature Ive never seen behaves
# I would be down
# Hmm. A message was deleted
# Found a way
# I like killing people in the past personally lmfao
# Gray Man added
# Just make sure to mention x skill cause y reason
# As long as you can justify it Ill most likely approve it
# What was that
# I might use some of those metagame artifacts
# One sec
# Funnier if its blackwater
# @everyone down for tonight?
# I CAN GNOME TODAY
# I also might want to make this guy a fighter instead
# Just kinda waiting to see if mom still wants me to come
# Thats just immunity to fear for 2k
# Am stupid
# I mean there is an archtype for seige weapons...
# I should just give Lawrence half my stuff since I overprepare and he underprepares
# Wait seriously
# So I just said screw it and studied for midterm
# Both are like the same amount of almost finished but doing kingmaker is fair to keep it rolling
# On a scale of 1-10 how much should I spec towards killing Mariah Carey
# 1: I build a character using none of the context
# 10: I am immune
# they lose their stuffing lmao
# close enough
# at 8
# @everyone who is interested please react here with a 🪙
# New map? What?
# Lollipop Lagoon Tree Swing 😎
# Chefs is kinda sus
# i spose
# What time
# Got my weeks off
# i do
# I close this weekend
# Azata dragon go crazy
# So no gnome
# That part was good on time. Leading up to getting to Cliffhall was the issue
# She said she was surprised people wouldn't show up
# I mean technically speaking other people can too I just know these people play
# I'm not exactly sure how I'd get immunity to mental and auditory effects, but I'll try
# My character would have to exist to do so
# Free sun
# <@!151500793990742016> <@!146626274066956288> <@!151489352164311040> how about you guys
# When Randall said he had horns I realized it
# or is it the change shape monster ability
# Level 3!
# Doesn’t mean evil character is illegal though
# Gotta go get some shid done so I’m not sure on if I’ll be done on time
# This is a funny item
# I'm still good
# Okay <@&1064607664216231997> we need to work out a time
# i am with parents then
# from you
# This is a threat
# Oh gotcha
# Sorry Im tired out rn
# The website law sent
# or during downtime
# It does not have thay
# All I need to know is how strong I need to be to hold onto a ships cannons without a ship attached
# In short you are free to level up
# Will be good then
# we only murdered some of them
# the letters "ac" appear in the wizard spell list 444 times but only 443 times in the sorcerer spell list
# You guessed the name
# +3000gp  in potions
# Wait its at 4:48 so it will be good
# Guess what other spell is illegal
# are you ton or ten
# Just stumbled onto it
# <@!318536129727168512> <@!531348109347782656> ?
# Also Noah forgot to tell you yesterday but you get a heropoint in both campaigns
# what chicanery are you up to
# I’m good either way
# Because “We really wanted to reinforce that all of the game’s races are just as flexible as humans when it comes to the range of culture and personality,”
# Sat 5-8 yay or nay
# <@151489352164311040>  :game_die:
# **Result**: 1d20 (5) + 3
# **Total**: 8
# Thought you were talking irl for a second
# Maybe not
# In Evermore's setting, I also grouped dragons based off of type of magic
# I'll write you a summary Randall
# How tf we supposed to know
# There is an antipaladin archtype that is baisically an antidruid
# You can roleplay it as a sort of "very specific intelligence" kinda thing
# Let me know if you want to use a one shot box
# You gonna be in waynesville?
# wild magic basically makes it so if you fuck up a spell random shit happens
# <@151489352164311040> <@235883733985525760>
# thats good
# anyways
# time to singlehandedly reduce the odogaron population for a slightly better friendship bracelet
# Didn't realize you could do that
# <@&927426307514581042> ?
# Im free all week more or less (friday unknown)
# You guys have fun...
# Thining about this more both days are equally good for me so idrc
# hear me out
# make it into kingmaker
# and our 2 charcters just do a fusion
# I think
# i will spread the good word of cheap mhw
# *think I used for him
# That's cool
# 710 from sessions alone before that
# ...
# Did Randall get learned
# I'm out here with big things and you two got
# Pursuit and eldritch
# Do I want True Strike or Spellstrike more
# I did that without trying lol
# <@378709482953244672> you still interested?
# I ended up going to asheville at 12 and just got back so I'll prolly be good
# Skeleton Champion cohort sounds pog
# of damage
# Just gotta make charkter
# pretty much
# Also I'm having to go to asheville with mother
# You ever grind Jetpack Joyride, Subway Surfers, or another mobile game
# So were people feelin Gnomes, Werewolf, or busy
# not sure how thats gonna work out lol
# Oh I see
# Wunna recreate my poor character from my last try at starfinder 1e, man with biggest gun he could find
# It’s more of a general and his captain thing
# Cause bloodline didnt change spell type in 1e
# And then Wizard and somebody else
# he has an appreciation for intricate armors
# i feel like being a living creature and having the undead trait are mutually exclusive
# I think ttrpg does that automatically basically
# dis wat im sitting at
# Also Archives and d20 are cool
# Or maybe something else idk
# ok hear me out
# in other news Archives 😔
# o shit, ive remembered two random mmo's that i dumped part of my childhood into
# JumpStart and another i cant remember the name of
# + cant cast verbal
# Which is why I'm confused at this site I've never seen before lol
# I am
# i see
# currently working on a lower magic system for a hunger games type rpg
# Its +2, so I have a +14
# Im free but idk if that matters now
# Since you are now a bat
# works for me
# bone shaped meat grinder
# If TJ is up for it I am down to do either AP today. If not we can just do kingdom building @everyone.
# DO NOT WAKE TRISTIN FROM HIS NAP I AM AWARE HE WILL BE LATE
# Enlarge person works on Humans, Dwarves, Ratfolk, Tengu, Literal fucking monkey, and giants
# Doesn't work on most half humans Aasimar, Tiefling, Oread, Ifrit, etc.
# So what is everyones status tomorrow <@&927426307514581042>
# Eating lunch
# Oh right
# Got the armor from it and all
# <@&828644080443326494> gonna try for tomorrow at early time
# considering thats basically the replacement for evil
# I think it may just be the check penalty, but i wasn't 100% sure
# Prolly tho I forgot I have my dmv appointment then as well but I doubt it'll be after 5
# <@458413180893397022> hopefully I'll see you again fall 2022
# They get 3.5 for d6, 4.5 for d8, 5.5 d10, 6.5 for d12
# Cause guess who doesnt worship Shylen
# Oh nvm
# K we can start in like 5-10 min
# Everyone knows communisim makes any song 50% better
# Trickster does stay in the crpg though
# Trickster is very funny
# other races do though
# The only thing that I wasn't already gonna get was the ranks in knowledge arcana
# Theoretically that should work
# If you have any preference over fighter
# <@318536129727168512>
# I was just informed of a quirky detail on windy escape
# I feel like there should be a way 2e kin can do void
# <@!151500793990742016>  :game_die:
# **Result**: 1d8 (3)
# **Total**: 3
# I will roll one of them
# Is that a 1e ap
# We could also do it outside if tristin wants to bring a foldable table but
# One benefit of this is I just gained the ability to make a summoner and eidolon share a health pool
# Turn the Wheel of Seasons is a pretty wonderful feat
# Tjs fat +8
# Alright TJ and Randall said yes
# Lmao literal gloomblade
# Hold on it gets worse
# +all the bells and whistle belts and stuff for the party
# on thursday
# human bodys are expensive
# I figured
# Trust me it'll be funny
# Shaking my glock
# And is also impressive that it hasn't been nuked by wotc yet
# Not that I can recall off the top of my head
# If @everyone is down we should probably do that today then. Cause we can’t do it tomorrow.
# was looking at buying it
# But this is a trial so it is repeatable
# Hey did any of ya'll put ranks in diplomacy
# Yknow unless presdigitation helps with smell, I think my bard probably smells like a literal slaughter house
# Like make x npc like you and you can lich on em
# 25k sounds a lot better than 120k
# That made me die inside
# You def aren't the sole reason for that decision. I've had doubts about it
# So up to <@151489352164311040>
# or monastic archery
# Oh I get it now
# I do not have access to its stats
# that makes me sad
# Also when, is it 5?
# Makes sense
# I would imagine it's too heavy to swim in
# that's how i got it
# @everyone ^
# <@&927426307514581042> In Zeds 1st shipment of goods the most notable item is:
# Wand of Magic Missile (1st) (23 of 50 charges) (345 gp)
# it simply is
# I was condused cause <@456226577798135808> didn't use <#842138493932666940>
# Oh I just saw this
# he's definitely a charisma caster
# Learn create water and then repeat cast it so the crab can always swim
# You da best chief
# you should take it off
# Yeah I got it the first time
# What would he get retrained as?
# Him being an Inquisitor could be sick
# No it was kinda mid meta wise
# But really fun mechanically
# Also down just struggling to find the right flavor for my build
# So I can battle medicine using Occultism instead of Medicine
# No Animist, Bard, Barbarian (Fully), Cleric, Gunslinger, Magus, Psychic, Rogue, Sorcerer, Witch
# You know I think min making umd is the progamer move to fix my spell troubles
# <@&828644080443326494> today at 1
# But it's on the list for party comp so I assume it is allowed
# You could run a dnd/pathfinder 1shot like a werewolf game now that I think of it
# maybe allow fun things <a:yawning_peep:939966850266181662>
# I got no shot of making it 💀
# ima jump in if i can
# But idk
# No, it is evolving
# <@318536129727168512> Are you able to open up the Foundry for a minute?
# I’m gonna make him a fighter
# Spicy food 👀
# i was looking at that too
# my uncle loves sams club
# How dare you anonymize me
# i was looking at it on my phone so it was a bit confusing
# I did not think about that
# ignore the fact i literally have the same thing
# ima be using a controller 100%
# Yeah Irori ain't boring he just doesn't do much
# "Every bard spell has a verbal component (song, recitation, or music)."
# I like to think my bard has a leitmotif in my inspire courage and my animate dead
# We buy a pet
# Or a Barbarian with barroom brawler
# I like this guy
# I mean looking at tyrant its litterally nothing
# Natural Spell is a sick feat for a druid btw
# Since Arazni is getting promoted
# no I just like to limit it
# Brace: If you use a readied action to set a brace weapon against a charge, you deal double damage on a successful hit against a charging character (see Chapter 8).
# <@!151500793990742016> Make carroter
# everyday but one day i will have to leave at 7/8 (prob tues or thurs)
# And how you spell Bovian Kings name?
# Hey <@318536129727168512> can I attempt a craft alchemy check to collect ghost salt from ash mans remains
# Does that == gestalt
# Ah I knew it was a state ip
# i punch
# But it's aimed at rouges anyway
# That is the case right now though. Since most mindless (not undead) are grouped under N
# If anything I would just like for you guys to let me know if you have something coming up so I can cancel or reschedule the game instead of sitting there for 2 hours to eventually say it is too late
# Aight so nah
# We need to come up with a name for the evil organization
# <@!151489352164311040> valenkryst wants your attention ^
# hows it going
# Before I continue I want to ask what people want/expect from a hunger games style ttrpg?
# I'll just add the immunity so he doesn't get cheesed
# Assuming i don't get a call from Walmart saying otherwise, yes
# Feyhunter seems to be vibing
# what question
# similar to pf but combo int and wis
# That is valid
# Why in Kingmaker
# There is no specifically desert giant heritage but goliath and maybe fire fit the bill
# Also that Lawrence guy 👎
# Gonna stick with 7 need to meet up with my uncle
# Main points are Have your shit together x5, show up, pay attention, and exist
# I was gonna put echos foundry on later but I guess not
# They aren't necessarily counter parts
# dont forget the part where you feed your minions with the garden
# okay then I'll be good after 3PM
# What was the buy price in blackwater
# I use the free pathbuilder on mobile and the paid one on browser
# He said Wednesday he is typically off
# And I never will
# I'll port your air
# pog x2
# earth, water, electric, and fire beat
# Yeah for me it's always I could buff, debuff, move to tank, move to flank, fullround/attack, use an alchemical item to finess something
# A 1 level  dip sounds nice
# <@151489352164311040> What your schedule
# I just looked it out of interest a few minutes ago
# Making tristin call me asinine is entertaining
# 9. That Sergeant Hallack is a coward! He quit the army
# and now lets all his comrades march to war why he sits
# on his duff, drinking his cares away.
# 10. Have you seen Bianca DeVallya? She plays at
# Canton’s Canter almost every night. She’s an angel -- the
# most beautiful lass I’ve ever seen!
# 11. Sister Marta saved my life. I’ll never be able to repay that blessed angel of Mitra.
# 12. Those strange hills in the Briar are haunted no two
# ways about it. Anyone who goes there isn’t coming back!
# 13. The Bugbears are marching towards Farholde!
# We’ve got evacuate the city!
# 14. Old One-Eye’s back. He’s half-tiger, half-devil that
# old cat! Big as a house!
# 15. Lorringsgate’s ... gone! Can you believe it? First
# Balentyne and now Lorringsgate! Can anyone stop these
# monsters?
#  16. The Knights of the Alerion have gone mad and
# are blaming the invasion on the temple of Asmodeus.
# They’re burning anyone with a black cat at the stake! It’s
# madness! There hasn’t been a cult of Asmodeus in Talingarde for twenty years. Someone’s organizing the bugbears, surely, but Asmodeans? Ha!
# 17. Lord Welshire may have gone to war but at least
# Sir Valin still mans the Castle Farthyn. A knight of true
# noble blood, he is! Why, they say he is distant kin of the
# Victor himself!
# 18. The Baron Vandermir is a strange one! The elf
# hardly ever leaves his manor these days.
# 19. The Baron Vandermir is the most generous man
# I’ve ever met. It’s because of him this town has an orphanage.
# 20. The kids at the Vandermir Orphanage are little
# more than thugs! I hear the corrupt old baron sometimes
# uses them for muscle.
# That is fair, i do suck for that
# I won't have to imagine here soon
# forgot that existed
# Basically I made an oopsie when I was still a pretty fresh dm in 1e
# so i can but itll be tight
# Technical difficulties
# i saw closed s day, my brain edited out the un so i skipped over that sig
# oh true
# Basically same situation once again
# Replacing lowes with the attic
# <@458413180893397022> thoughts on everyone taking a level dip in dual cursed oracle
# ya know it
# sunday will no work for me this week
# he's just really passionate
# Too much rock idk
# more square
# 2e made me enjoy martials again 1e rocket tag is rough
# im sure theres a way
# Short gnome session Tues then?
# Makes sense
# one attack for 2 actions
# Arcane: Mirage and Fortune
# Primal: Adamantine and Horned
# Divine: Diabolic
# Occult: Conspirator
# what else would i do
# oh no...
# ranger dedication + basic hunter's trick > hunted shot bouta go crazy
# <@&828644080443326494> monday 5?
# Also are we just gonna tell people our test character ideas?
# +Character images
# Correct lmfao
# i know what that is thanks to you
# They actually farmed for XP
# <@&927426307514581042> ya'll interested in starting a tad early?
# I don’t work Wednesday
# they also did it so it scales depending on the characters level which was something I thought 1e needed
# Yeah but from what I've gathered Furic would have been a valid target for the siphon but his bird wouldn't
# I have another pf2e oneshot in the wings. I will save it for now but know it is available.
# Sorry gonna have to skip today I gotta work on Civics shit
# No gnome today btw Ive been busy nonstop for about a week and need a day to chill
# I'm good either way. Seems like for Fable sake it'd be simpler to do gnome.
# I see there being like 3 different ways we could go
# 1. Go save zed
# 2. Go do some clandestine shit in smallsburogh
# 3. Go south and find krilin / onry
# What about Monday?
# I cant sell it
# My shitty laptop just ran out battery, be on in a sec to hear anything final
# lmfao or something similarily dumb
# Also <@378709482953244672> this  you
# Tomorrow @5?
# <@&927426307514581042>
# Negating crits is pretty powerful
# didnt know that
# Can Kingmaker 2 see it?
# You stopped them from finishing book 1 though
# I will probably do a foundry intro session before the first session
# Dam, I guess they theory they were killing off nethys so they wouldn't have to update archives was false
# So lycanthropy
# At least I don't have to worry about a Startossing nazi lmfao
# Situational allies
# Next purchase goal: Barding
# Only issue was my stupid ass making maps
# So maybe just do that at critical?
# already came to a conclusion
# In the case of monsters its overarching so I think it is flexible to say these ones don't do that
# Guess I just need to build for a quickened bungle
# its a platapus
# But tldr is just this unless you are a crafter or caster that needs expensive components (diamond dust, onyx, etc)
# heavy bowgun trivializes the game so much lmao
# Okay when do you not
# Everyone willing to pitch in like $5 for a pizza fund
# I kinda hijacked that entire segment of magic in a not-so-subtle way for my West March setting, so it'll be interesting weaving it in
# We doing 5 or something
# I think you could reflavor wood as bone and just flip vitality to void
# That one is interesting
# I love that feat
# Are you shooting blasts or casting?
# oh yes
# Be a werebat-kin, take bat shape to turn into a tiny bat, take mischievous and grasping tail so you tail counts as a hand for all purpose, and finally become an air kineticist so you can be a tiny bat who summons lightning and hurricanes with your tail
# I mean...
# Lunge + big + sarissa = ranged attacks
# or sausage
# If it says Im good Im good
# Small picture mode neat
# I’ve heard that Father Donnagin was sent here
# after the church demoted him from bishop. He
# got into some sort of trouble – serious trouble I’d
# wager to be banished to the Watch Wall.
# eight <:wah:951310823366754334>
# Look Furic just has some crazy phantom limb syndrome
# Ethical is kinda like laws (think code of ethics)
# Moral is like learned from community
# Personal is an ideal that is different from your peers
# noah when someone mispells his last name
# My favorite part is even if they do this one they prob won't give us a name lmfao
# Me when I meant on normal school days 😔
# Okay guys want to make some Bards for me
# I’m gonna be 30 minutes late… I’m deciding whether or not I should still go
# i gotchu
# I'm totally fine when it comes to your mom giving you stuff to do
# Oh shit
# Also next god should be declared safe in like 2 min cause time change
# Please tell me wholesome/unwholesome is now just a trait things can have
# I am medicated as hell though so I don't feel anything
# <@!458413180893397022> type faster
# Werebat-kin don’t have a tail initially
# I leave sometime next year hopefully
# Question. Where is the dog currently?
# As long as what they are doing actually helps them Idrc
# It was ADnD1e
# 20 dual class 10 mythic free archetype ancestral paragon
# it is not, unfortunately
# anyone missing a story mission? If you are level 3 and I have your backstory you should have one.
# The hall maybe?
# Today at 5 <@&927426307514581042>
# 6 hour long dual session
# I guess I should maybe not make this character in that case
# we can just get pizza hut to deliver
# make him a paladin
# How is pizza gonna work
# I can do pf while I'm driving 🚗
# and now "magic ore" exists
# I dunno about tristin
# That's hella quirky
# honestly i could swap club penguin out for roblox
# This is funny cause the campaign is about a werewolf plague
# Fire may be a problem
# Can’t have double ability to a stat
# Uh, trick it to fall into a hole
# It seems like every session we have I start clueless with 0 idea whats going on and it takes me a bit to understand whats happening
# I'm down if others are
# something = lawrence
# id leave at 6 but im gonna guess we would be done by then
# The winner of the tournament gets a free reroll in kingmaker and wotw
# Finding better modules n shit, making maps, etc.
# nvm on dayjob then
# Still working on who I will be to fit the build
# O fuck I forgot about this
# I am good
# 5032
# 5032
# 5032

# %%
# Add the new features to a matrix

X_train_features = np.column_stack((numWordsTrain, numCharTrain, avgCharTrain))
display(X_train_features.shape)
X_test_features = np.column_stack((numWordsTest, numCharTest, avgCharTest))
display(X_test_features.shape)
# Out:
# (5032, 3)
# (78, 3)

# %%
# Fit a KNN model to the data
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for i in range(1, 51):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train_features, Y_train)

    # Predict the usernames of the test set
    Y_pred = knn.predict(X_test_features)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(Y_test, Y_pred)
    print(accuracy)
# Out:
# 0.16666666666666666
# 0.21794871794871795
# 0.21794871794871795
# 0.1794871794871795
# 0.14102564102564102
# 0.14102564102564102
# 0.16666666666666666
# 0.23076923076923078
# 0.19230769230769232
# 0.1794871794871795
# 0.15384615384615385
# 0.16666666666666666
# 0.14102564102564102
# 0.14102564102564102
# 0.14102564102564102
# 0.14102564102564102
# 0.1282051282051282
# 0.15384615384615385
# 0.14102564102564102
# 0.14102564102564102
# 0.1282051282051282
# 0.1282051282051282
# 0.1282051282051282
# 0.1282051282051282
# 0.15384615384615385
# 0.1282051282051282
# 0.14102564102564102
# 0.15384615384615385
# 0.14102564102564102
# 0.14102564102564102
# 0.14102564102564102
# 0.14102564102564102
# 0.1282051282051282
# 0.1282051282051282
# 0.15384615384615385
# 0.15384615384615385
# 0.1282051282051282
# 0.10256410256410256
# 0.10256410256410256
# 0.11538461538461539
# 0.10256410256410256
# 0.10256410256410256
# 0.10256410256410256
# 0.11538461538461539
# 0.1282051282051282
# 0.1282051282051282
# 0.11538461538461539
# 0.11538461538461539
# 0.1282051282051282
# 0.11538461538461539

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train_features, Y_train)

# See how the model predicts the usernames of a small set of test messages
# This first message is from author13, the model should get this right since this comes from the training set
# Interestingly, the model gets this wrong
print("Train")
message = "Oh fair I guess that could be it"
words = message.count(" ") + 1
char = len(message)
avgChar = char / words
X_test_message = np.array([[words, char, avgChar]])
print(knn.predict(X_test_message))
# This message is from author14, the model should get this right since this comes from the training set
message = "We're allowed to take two archetypes at level 2, right?"
words = message.count(" ") + 1
char = len(message)
avgChar = char / words
X_test_message = np.array([[words, char, avgChar]])
print(knn.predict(X_test_message))
# These next 10 messages are not in the training set, so the model will have to predict the author
# The authors of these messages are respectively authors 4, 2, 14, 4, 13, 2, 10, 4, 10, 13
messages = ["new logo looks pretty pog",
 "And Thetis king was Ferguis?", 
 "Doing certain mythic paths where you ascend as a certain type of creature (angel/azata/demon/lich) vs more standard powers", 
 "I enjoyed when Gorgar Gorged all over them.",
 "Oh no the Pharaoh is using sacred geometry", 
 "fyi im busy from like 12:30 till like 2:45 the next 4 saturdays",
 "It was like the funnest alternative first person shooter I've ever played", 
 "It isn't actually severed. Just the general term for the effect. If it auto kills I'd prob have to make it be more vp than the others",
 "Hey how do yall feel about trying a house rule of confirming fumbles? Instead of an auto AOO?",
 "He thought there was no gnome because he thought I was busy when I was not busy"
]
print("Test")

for msg in messages:
    words = msg.count(" ") + 1
    char = len(msg)
    avgChar = char / words
    X_test_message = np.array([[words, char, avgChar]])
    print(knn.predict(X_test_message))
# Out:
# Train
# ['author4']
# ['author14']
# Test
# ['author10']
# ['author4']
# ['author4']
# ['author4']
# ['author4']
# ['author5']
# ['author4']
# ['author13']
# ['author4']
# ['author16']
